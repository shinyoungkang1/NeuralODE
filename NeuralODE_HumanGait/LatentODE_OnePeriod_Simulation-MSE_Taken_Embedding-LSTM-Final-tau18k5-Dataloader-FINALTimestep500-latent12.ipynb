# %%
import os
import argparse
import logging
import time
import numpy as np
import numpy.random as npr
import matplotlib
matplotlib.use('agg')
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torchdiffeq import odeint_adjoint as odeint
from torch.utils.data import DataLoader
os.environ['KMP_DUPLICATE_LIB_OK']='True'

# %%
samp_trajs_TE = torch.load('samp_trajs_TE_tau18k5_timestep500.pt')
samp_trajs_val_TE = torch.load('samp_trajs_val_TE_tau18k5_timestep500.pt')

tau = 18
k = 5
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

batch = 144

ts_num = 2.5
tot_num = 500

samp_ts = np.linspace(0, ts_num, num=tot_num)
samp_ts = torch.from_numpy(samp_ts).float().to(device)

orig_trajs_TE = np.load('orig_trajs_TE_tau18k6_timestep500.npy')
orig_trajs_TE = orig_trajs_TE.reshape(72, 1310, 6*(k+1))
samp_trajs_TE_test = orig_trajs_TE[:, :tot_num, :]
samp_trajs_TE_test = torch.from_numpy(samp_trajs_TE_test).float().to(device).reshape(72, tot_num, 6*(k+1))

#Load to Dataloader
train_loader = DataLoader(dataset = samp_trajs_TE, batch_size = batch, shuffle = True, drop_last = True)
val_loader = DataLoader(dataset = samp_trajs_TE, batch_size = 72, shuffle = True, drop_last = True)

# %%
class LatentODEfunc(nn.Module):

    def __init__(self, latent_dim=8, nhidden=50):
        super(LatentODEfunc, self).__init__()
        #self.tanh = nn.ELU(inplace= True)
        self.tanh = nn.Tanh()
        self.fc1 = nn.Linear(latent_dim, nhidden)
        self.fc2 = nn.Linear(nhidden, nhidden)
        self.fc3 = nn.Linear(nhidden, latent_dim)
        self.nfe = 0

    def forward(self, t, x):
        self.nfe += 1
        out = self.fc1(x)
        out = self.tanh(out)
        out = self.fc2(out)
        out = self.tanh(out)
        out = self.fc3(out)
        return out

class RecognitionRNN(nn.Module):

    def __init__(self, latent_dim=8, obs_dim=46, nhidden=50, nbatch=1):
        super(RecognitionRNN, self).__init__()
        self.nhidden = nhidden
        self.nbatch = nbatch
        #self.h1o = nn.Linear(obs_dim, latent_dim*4)
        #self.h3o = nn.Linear(latent_dim*4, latent_dim*2)
        #self.lstm = nn.LSTMCell(latent_dim*2, nhidden)
        self.h1o = nn.Linear(obs_dim, 12)
        self.h3o = nn.Linear(12, 6)
        self.lstm = nn.LSTMCell(6, nhidden)
        self.tanh = nn.Tanh()
        self.h2o = nn.Linear(nhidden, latent_dim*2)

    def forward(self, x, h, c):
        xo = self.h1o(x)
        xo = self.tanh(xo)
        xxo = self.h3o(xo)
        hn, cn = self.lstm(xxo, (h,c))
        hn = self.tanh(hn)
        out = self.h2o(hn)
        return out, hn, cn
    

    def initHidden(self):
        return torch.zeros(1, self.nbatch, self.nhidden)


class Decoder(nn.Module):

    def __init__(self, latent_dim=8, obs_dim=46, nhidden=50):
        super(Decoder, self).__init__()
        self.relu = nn.ReLU(inplace=True)
        self.tanh = nn.Tanh()
        self.fc1 = nn.Linear(latent_dim, nhidden)
        self.fc2 = nn.Linear(nhidden, nhidden*2)
        self.fc3 = nn.Linear(nhidden*2, obs_dim)

    def forward(self, z):
        out = self.fc1(z)
        out = self.tanh(out)
        out = self.fc2(out)
        out = self.tanh(out)
        out = self.fc3(out)
        return out


class RunningAverageMeter(object):
    """Computes and stores the average and current value"""

    def __init__(self, momentum=0.99):
        self.momentum = momentum
        self.reset()

    def reset(self):
        self.val = None
        self.avg = 0

    def update(self, val):
        if self.val is None:
            self.avg = val
        else:
            self.avg = self.avg * self.momentum + val * (1 - self.momentum)
        self.val = val


def log_normal_pdf(x, mean, logvar):
    const = torch.from_numpy(np.array([2. * np.pi])).float().to(x.device)
    const = torch.log(const)
    return -.5 * (const + logvar + (x - mean) ** 2. / torch.exp(logvar))

def mseloss(x, mean):
    loss = nn.MSELoss()
    return loss(x, mean)

def normal_kl(mu1, lv1, mu2, lv2):
    v1 = torch.exp(lv1)
    v2 = torch.exp(lv2)
    lstd1 = lv1 / 2.
    lstd2 = lv2 / 2.

    kl = lstd2 - lstd1 + ((v1 + (mu1 - mu2) ** 2.) / (2. * v2)) - .5
    return kl

def MSELoss(yhat, y):
    assert type(yhat) == torch.Tensor
    assert type(y) == torch.Tensor
    return torch.mean((yhat - y) ** 2)


def get_args():
    return {'latent_dim': latent_dim,
            'obs_dim': obs_dim,
            'nhidden': nhidden,
            'dec_nhidden' : dec_nhidden,
            'rnn_nhidden': rnn_nhidden,
            'device': device}

def get_state_dicts():
    return {'odefunc_state_dict': func.state_dict(),
            'encoder_state_dict': rec.state_dict(),
            'decoder_state_dict': dec.state_dict()}

def data_get_dict():
    return {
        'samp_trajs_TE': samp_trajs_TE,
        'samp_trajs_val_TE': samp_trajs_val_TE,
        'samp_ts': samp_ts,
    }

def get_losses():
    return {
        'train_losses': train_losses,
        'val_losses': val_losses,
        'val_losses_k1': val_losses_k1,
        'val_losses_k2': val_losses_k2,
        'val_losses_k3': val_losses_k3,
        'val_losses_k4': val_losses_k4,
        'val_losses_k5': val_losses_k5
    }

def save_model(tau, k, latent_dim, itr):

    save_dict = {
        'model_args': get_args(),
        'optimizer_state_dict': optimizer.state_dict(),
        #'data': data_get_dict(),
        'train_loss': get_losses()
    }
    
    save_dict.update(get_state_dicts())
    
    torch.save(save_dict, 'model/ODE_TakenEmbedding_RLONG_rnn2_lstm{}_tau{}k{}_LSTM_lr0.008_latent{}_LSTMautoencoder_Dataloader_timestep{}_Trial2_epoch{}.pth'.format(rnn_nhidden, tau, k, latent_dim,tot_num, itr))

    
def data_for_plot_graph(gen_index):
    with torch.no_grad():
        # sample from trajectorys' approx. posterior

        ts_pos = np.linspace(0, ts_num*gen_index, num=tot_num*gen_index)
        ts_pos = torch.from_numpy(ts_pos).float().to(device)
    
        h = torch.zeros(1, samp_trajs_TE_test.shape[0], rnn_nhidden).to(device)
        c = torch.zeros(1, samp_trajs_TE_test.shape[0], rnn_nhidden).to(device)
    
        hn = h[0, :, :]
        cn = c[0, :, :]
    
        for t in reversed(range(samp_trajs_TE_test.size(1))):
            obs = samp_trajs_TE_test[:, t, :]
            out, hn, cn = rec.forward(obs, hn, cn)
        qz0_mean, qz0_logvar = out[:, :latent_dim], out[:, latent_dim:]
        epsilon = torch.randn(qz0_mean.size()).to(device)
        z0 = epsilon * torch.exp(.5 * qz0_logvar) + qz0_mean

        # forward in time and solve ode for reconstructions
        pred_z = odeint(func, z0, ts_pos).permute(1, 0, 2) #change time and batch with permute
        pred_x = dec(pred_z)
        
        return pred_x, pred_z
    
def plot_graph(gen_index, times_index, tot_index, dataset_value, deriv_index, pred_x_forgraph, orig_trajs, itr, path):
    with torch.no_grad():
        orig_trajs_forgraph = orig_trajs
        ts_pos_combined = np.linspace(0, ts_num*tot_index, num=tot_num*tot_index) 
        
        fig, axes = plt.subplots(nrows=6, ncols=1, figsize=(15, 9))
        axes = axes.flatten()
        
        for i, ax in enumerate(axes):
            ax.scatter(ts_pos_combined[times_index:times_index+tot_num*gen_index], orig_trajs_forgraph[dataset_value,times_index:tot_num*gen_index, i*(k+1)+deriv_index], s = 5)
            ax.plot(ts_pos_combined[times_index:times_index+tot_num*tot_index], pred_x_forgraph[dataset_value, times_index:times_index+tot_num*tot_index, i*(k+1)+deriv_index], 'r')
            ax.set_ylim(-3, 3)

        
        plot_name = 'lstm_datasetnum{}_latent{}_gen{}_deriv{}_epoch{}.png'.format(dataset_value, latent_dim, tot_index, deriv_index, itr)
        save_path = os.path.join(path, plot_name)
        plt.savefig(save_path, dpi=500)
        plt.close()

# %%
latent_dim = 12
nhidden = 64
dec_nhidden = 12
obs_dim = 6*(k+1)
rnn_nhidden = 256
nitrs = 8000
noise_std = 0.2

# %%
func = LatentODEfunc(latent_dim, nhidden).to(device)
rec = RecognitionRNN(latent_dim, obs_dim, rnn_nhidden, batch).to(device)
dec = Decoder(latent_dim, obs_dim, dec_nhidden).to(device)
params = (list(func.parameters()) + list(dec.parameters()) + list(rec.parameters()))
optimizer = optim.Adam(params, lr=0.008)
loss_meter = RunningAverageMeter()

train_losses = []
val_losses = []
val_losses_k1 = []
val_losses_k2 = []
val_losses_k3 = []
val_losses_k4 = []
val_losses_k5 = []
torch.cuda.empty_cache()

# %%
for itr in range(5001, nitrs+1):
    for data in train_loader:
        optimizer.zero_grad()
        h = rec.initHidden().to(device)
        c = rec.initHidden().to(device)
        hn = h[0, :, :]
        cn = c[0, :, :]
        for t in reversed(range(data.size(1))):
            obs = data[:, t, :]
            out, hn, cn = rec.forward(obs, hn, cn)
        qz0_mean, qz0_logvar = out[:, :latent_dim], out[:, latent_dim:]
        epsilon = torch.randn(qz0_mean.size()).to(device)
        z0 = epsilon * torch.exp(.5 * qz0_logvar) + qz0_mean   
        
        # forward in time and solve ode for reconstructions
        pred_z = odeint(func, z0, samp_ts).permute(1, 0, 2)
        pred_x = dec(pred_z)

        # compute loss
        loss = MSELoss(pred_x, data)
        loss.backward()
        optimizer.step()
        train_losses.append(loss.item())
        
    with torch.no_grad():
        for data_val in val_loader:
            h = torch.zeros(1, 72, rnn_nhidden).to(device)
            c = torch.zeros(1, 72, rnn_nhidden).to(device)
            hn = h[0, :, :]
            cn = c[0, :, :]
            
            for t in reversed(range(data_val.size(1))):
                obs = data_val[:, t, :]
                out, hn, cn = rec.forward(obs, hn, cn)
            qz0_mean, qz0_logvar = out[:, :latent_dim], out[:, latent_dim:]
            epsilon = torch.randn(qz0_mean.size()).to(device)
            z0 = epsilon * torch.exp(.5 * qz0_logvar) + qz0_mean

            #forward in time and solve ode for reconstructions
            pred_z = odeint(func, z0, samp_ts).permute(1, 0, 2)
            pred_x = dec(pred_z)
        
            #val_loss = MSELoss(pred_x, samp_trajs_val_TE) + torch.mean(-0.5 * torch.sum(1 + qz0_logvar - qz0_mean**2 - torch.exp(qz0_logvar), dim = -1)/(31*(k+1)+2))
            val_loss = MSELoss(pred_x[:,:,::(k+1)], data_val[:,:,::(k+1)])
            val_loss_k1 = MSELoss(pred_x[:,:,1::(k+1)], data_val[:,:,1::(k+1)])
            val_loss_k2 = MSELoss(pred_x[:,:,2::(k+1)], data_val[:,:,2::(k+1)])
            val_loss_k3 = MSELoss(pred_x[:,:,3::(k+1)], data_val[:,:,3::(k+1)])
            val_loss_k4 = MSELoss(pred_x[:,:,4::(k+1)], data_val[:,:,4::(k+1)])
            val_loss_k5 = MSELoss(pred_x[:,:,5::(k+1)], data_val[:,:,5::(k+1)])
            val_losses.append(val_loss)
            val_losses_k1.append(val_loss_k1)
            val_losses_k2.append(val_loss_k2)
            val_losses_k3.append(val_loss_k3)
            val_losses_k4.append(val_loss_k4)
            val_losses_k5.append(val_loss_k5)
            V = [val_loss, val_loss_k1, val_loss_k2, val_loss_k3, val_loss_k4, val_loss_k5]
            lowest_val_loss = torch.asarray(V).min(0)[0]
            deriv_index = torch.asarray(V).min(0)[1]

    if ((itr > 1000) and (itr % 15 == 0)):
        save_model(tau, k, latent_dim, itr)
        gen_index = 2
        times_index = 0
        tot_index = 10
        deriv_index = deriv_index.numpy()
        
        orig_trajs = orig_trajs_TE[:, 0:1300, :]

        pred_x, pred_z = data_for_plot_graph(tot_index)
        pred_x = pred_x.reshape(72, tot_num*tot_index, 6*(k+1))
        pred_z = pred_z.reshape(72, tot_num*tot_index, latent_dim)
        pred_x_forgraph = pred_x.detach().cpu().numpy()
        pred_z_forgraph = pred_z.detach().cpu().numpy()

        path = "Results_pic/tau{}k{}/longtimeseries/latent{}/Trial2_RLONG_data_loader_rnn2layer_lstm{}_lr0.008_timestep{}/epoch{}".format(tau, k, latent_dim, rnn_nhidden, tot_num, itr)

        if not os.path.exists(path):
           os.makedirs(path)

        
        tot_index = 2
        
        for i in range(72):
            plot_graph(2, times_index, tot_index, i, deriv_index, pred_x_forgraph, orig_trajs, itr, path)
            
        tot_index = 10
        
        for i in range(72):
            plot_graph(2, times_index, tot_index, i, deriv_index, pred_x_forgraph, orig_trajs, itr, path)


        
    print('Iter: {}, running avg mse: {:.4f} lowest val mse: {:.4f} at k {}'.format(itr, loss, lowest_val_loss, deriv_index))
# Out:
# Iter: 5001, running avg mse: 0.0880 lowest val mse: 0.0717 at k 3
# Iter: 5002, running avg mse: 0.1071 lowest val mse: 0.0934 at k 3
# Iter: 5003, running avg mse: 0.0893 lowest val mse: 0.0945 at k 2
# Iter: 5004, running avg mse: 0.0943 lowest val mse: 0.1078 at k 3
# Iter: 5005, running avg mse: 0.0883 lowest val mse: 0.0947 at k 3
# Iter: 5006, running avg mse: 0.0998 lowest val mse: 0.0896 at k 3
# Iter: 5007, running avg mse: 0.1154 lowest val mse: 0.0943 at k 4
# Iter: 5008, running avg mse: 0.1108 lowest val mse: 0.1476 at k 3
# Iter: 5009, running avg mse: 0.1265 lowest val mse: 0.0994 at k 3
# Iter: 5010, running avg mse: 0.2003 lowest val mse: 0.3094 at k 3
# Iter: 5011, running avg mse: 0.3873 lowest val mse: 0.8446 at k 4
# Iter: 5012, running avg mse: 0.7296 lowest val mse: 0.7800 at k 1
# Iter: 5013, running avg mse: 0.6595 lowest val mse: 0.6276 at k 3
# Iter: 5014, running avg mse: 0.4279 lowest val mse: 0.3853 at k 3
# Iter: 5015, running avg mse: 0.3488 lowest val mse: 0.3905 at k 0
# Iter: 5016, running avg mse: 0.3351 lowest val mse: 0.2832 at k 4
# Iter: 5017, running avg mse: 0.2684 lowest val mse: 0.2824 at k 1
# Iter: 5018, running avg mse: 0.2464 lowest val mse: 0.2145 at k 2
# Iter: 5019, running avg mse: 0.2311 lowest val mse: 0.1662 at k 4
# Iter: 5020, running avg mse: 0.1722 lowest val mse: 0.2989 at k 5
# Iter: 5021, running avg mse: 0.2768 lowest val mse: 0.1461 at k 3
# Iter: 5022, running avg mse: 0.1730 lowest val mse: 0.2263 at k 2
# Iter: 5023, running avg mse: 0.2004 lowest val mse: 0.1510 at k 4
# Iter: 5024, running avg mse: 0.1430 lowest val mse: 0.1337 at k 4
# Iter: 5025, running avg mse: 0.1584 lowest val mse: 0.1512 at k 2
# Iter: 5026, running avg mse: 0.1505 lowest val mse: 0.1168 at k 3
# Iter: 5027, running avg mse: 0.1295 lowest val mse: 0.1279 at k 3
# Iter: 5028, running avg mse: 0.1451 lowest val mse: 0.1353 at k 3
# Iter: 5029, running avg mse: 0.1381 lowest val mse: 0.1141 at k 2
# Iter: 5030, running avg mse: 0.1249 lowest val mse: 0.0996 at k 3
# Iter: 5031, running avg mse: 0.1171 lowest val mse: 0.0941 at k 2
# Iter: 5032, running avg mse: 0.1150 lowest val mse: 0.1073 at k 3
# Iter: 5033, running avg mse: 0.1159 lowest val mse: 0.1141 at k 3
# Iter: 5034, running avg mse: 0.1199 lowest val mse: 0.1198 at k 2
# Iter: 5035, running avg mse: 0.1140 lowest val mse: 0.1118 at k 3
# Iter: 5036, running avg mse: 0.1078 lowest val mse: 0.0908 at k 2
# Iter: 5037, running avg mse: 0.1199 lowest val mse: 0.1077 at k 3
# Iter: 5038, running avg mse: 0.1046 lowest val mse: 0.0923 at k 3
# Iter: 5039, running avg mse: 0.1037 lowest val mse: 0.0934 at k 3
# Iter: 5040, running avg mse: 0.0942 lowest val mse: 0.0857 at k 3
# Iter: 5041, running avg mse: 0.0904 lowest val mse: 0.0895 at k 3
# Iter: 5042, running avg mse: 0.0958 lowest val mse: 0.0856 at k 3
# Iter: 5043, running avg mse: 0.0921 lowest val mse: 0.0805 at k 3
# Iter: 5044, running avg mse: 0.0903 lowest val mse: 0.0887 at k 3
# Iter: 5045, running avg mse: 0.0899 lowest val mse: 0.0865 at k 3
# Iter: 5046, running avg mse: 0.0973 lowest val mse: 0.0868 at k 3
# Iter: 5047, running avg mse: 0.0911 lowest val mse: 0.0836 at k 3
# Iter: 5048, running avg mse: 0.0920 lowest val mse: 0.0788 at k 2
# Iter: 5049, running avg mse: 0.0910 lowest val mse: 0.0812 at k 3
# Iter: 5050, running avg mse: 0.0913 lowest val mse: 0.0831 at k 3
# Iter: 5051, running avg mse: 0.0884 lowest val mse: 0.0818 at k 3
# Iter: 5052, running avg mse: 0.0912 lowest val mse: 0.0807 at k 2
# Iter: 5053, running avg mse: 0.0888 lowest val mse: 0.0804 at k 3
# Iter: 5054, running avg mse: 0.0910 lowest val mse: 0.0780 at k 3
# Iter: 5055, running avg mse: 0.0902 lowest val mse: 0.0839 at k 3
# Iter: 5056, running avg mse: 0.0865 lowest val mse: 0.0835 at k 3
# Iter: 5057, running avg mse: 0.0923 lowest val mse: 0.0829 at k 3
# Iter: 5058, running avg mse: 0.0886 lowest val mse: 0.0816 at k 3
# Iter: 5059, running avg mse: 0.0904 lowest val mse: 0.0769 at k 3
# Iter: 5060, running avg mse: 0.0873 lowest val mse: 0.0818 at k 3
# Iter: 5061, running avg mse: 0.0841 lowest val mse: 0.0787 at k 3
# Iter: 5062, running avg mse: 0.0828 lowest val mse: 0.0796 at k 3
# Iter: 5063, running avg mse: 0.0880 lowest val mse: 0.0795 at k 3
# Iter: 5064, running avg mse: 0.0949 lowest val mse: 0.0836 at k 2
# Iter: 5065, running avg mse: 0.0850 lowest val mse: 0.0840 at k 3
# Iter: 5066, running avg mse: 0.0837 lowest val mse: 0.0968 at k 2
# Iter: 5067, running avg mse: 0.0814 lowest val mse: 0.0795 at k 3
# Iter: 5068, running avg mse: 0.0898 lowest val mse: 0.0860 at k 3
# Iter: 5069, running avg mse: 0.0879 lowest val mse: 0.0795 at k 3
# Iter: 5070, running avg mse: 0.0891 lowest val mse: 0.0766 at k 3
# Iter: 5071, running avg mse: 0.0912 lowest val mse: 0.0839 at k 3
# Iter: 5072, running avg mse: 0.0884 lowest val mse: 0.0769 at k 3
# Iter: 5073, running avg mse: 0.0882 lowest val mse: 0.0820 at k 3
# Iter: 5074, running avg mse: 0.0864 lowest val mse: 0.0746 at k 3
# Iter: 5075, running avg mse: 0.0827 lowest val mse: 0.0773 at k 3
# Iter: 5076, running avg mse: 0.0836 lowest val mse: 0.0811 at k 3
# Iter: 5077, running avg mse: 0.0899 lowest val mse: 0.0694 at k 3
# Iter: 5078, running avg mse: 0.0868 lowest val mse: 0.0804 at k 3
# Iter: 5079, running avg mse: 0.0900 lowest val mse: 0.0837 at k 3
# Iter: 5080, running avg mse: 0.0856 lowest val mse: 0.0736 at k 3
# Iter: 5081, running avg mse: 0.0828 lowest val mse: 0.0753 at k 3
# Iter: 5082, running avg mse: 0.0866 lowest val mse: 0.0719 at k 3
# Iter: 5083, running avg mse: 0.0836 lowest val mse: 0.0727 at k 2
# Iter: 5084, running avg mse: 0.0823 lowest val mse: 0.0813 at k 3
# Iter: 5085, running avg mse: 0.0856 lowest val mse: 0.0792 at k 3
# Iter: 5086, running avg mse: 0.0811 lowest val mse: 0.0773 at k 3
# Iter: 5087, running avg mse: 0.0861 lowest val mse: 0.0797 at k 3
# Iter: 5088, running avg mse: 0.0882 lowest val mse: 0.0716 at k 3
# Iter: 5089, running avg mse: 0.0957 lowest val mse: 0.0876 at k 3
# Iter: 5090, running avg mse: 0.0988 lowest val mse: 0.0977 at k 3
# Iter: 5091, running avg mse: 0.0843 lowest val mse: 0.0805 at k 3
# Iter: 5092, running avg mse: 0.0988 lowest val mse: 0.0815 at k 3
# Iter: 5093, running avg mse: 0.0926 lowest val mse: 0.0743 at k 3
# Iter: 5094, running avg mse: 0.1017 lowest val mse: 0.0860 at k 3
# Iter: 5095, running avg mse: 0.0976 lowest val mse: 0.0798 at k 3
# Iter: 5096, running avg mse: 0.1077 lowest val mse: 0.0893 at k 3
# Iter: 5097, running avg mse: 0.0963 lowest val mse: 0.0973 at k 4
# Iter: 5098, running avg mse: 0.1037 lowest val mse: 0.1067 at k 2
# Iter: 5099, running avg mse: 0.1152 lowest val mse: 0.1221 at k 4
# Iter: 5100, running avg mse: 0.1321 lowest val mse: 0.1127 at k 3
# Iter: 5101, running avg mse: 0.1088 lowest val mse: 0.0849 at k 3
# Iter: 5102, running avg mse: 0.1102 lowest val mse: 0.0831 at k 3
# Iter: 5103, running avg mse: 0.1109 lowest val mse: 0.0865 at k 2
# Iter: 5104, running avg mse: 0.0964 lowest val mse: 0.0838 at k 3
# Iter: 5105, running avg mse: 0.0872 lowest val mse: 0.1102 at k 3
# Iter: 5106, running avg mse: 0.1062 lowest val mse: 0.1041 at k 3
# Iter: 5107, running avg mse: 0.1104 lowest val mse: 0.0952 at k 3
# Iter: 5108, running avg mse: 0.0929 lowest val mse: 0.0760 at k 2
# Iter: 5109, running avg mse: 0.0933 lowest val mse: 0.0752 at k 3
# Iter: 5110, running avg mse: 0.0919 lowest val mse: 0.0841 at k 3
# Iter: 5111, running avg mse: 0.0877 lowest val mse: 0.0765 at k 3
# Iter: 5112, running avg mse: 0.0826 lowest val mse: 0.0703 at k 3
# Iter: 5113, running avg mse: 0.0886 lowest val mse: 0.0768 at k 3
# Iter: 5114, running avg mse: 0.0862 lowest val mse: 0.0794 at k 3
# Iter: 5115, running avg mse: 0.0813 lowest val mse: 0.0743 at k 3
# Iter: 5116, running avg mse: 0.0877 lowest val mse: 0.0770 at k 3
# Iter: 5117, running avg mse: 0.0774 lowest val mse: 0.0725 at k 3
# Iter: 5118, running avg mse: 0.0843 lowest val mse: 0.0724 at k 3
# Iter: 5119, running avg mse: 0.0870 lowest val mse: 0.0718 at k 3
# Iter: 5120, running avg mse: 0.0842 lowest val mse: 0.0777 at k 3
# Iter: 5121, running avg mse: 0.0836 lowest val mse: 0.0816 at k 3
# Iter: 5122, running avg mse: 0.0825 lowest val mse: 0.0694 at k 3
# Iter: 5123, running avg mse: 0.0807 lowest val mse: 0.0766 at k 3
# Iter: 5124, running avg mse: 0.0824 lowest val mse: 0.0744 at k 3
# Iter: 5125, running avg mse: 0.0849 lowest val mse: 0.0747 at k 3
# Iter: 5126, running avg mse: 0.0833 lowest val mse: 0.0749 at k 3
# Iter: 5127, running avg mse: 0.0839 lowest val mse: 0.0733 at k 3
# Iter: 5128, running avg mse: 0.0862 lowest val mse: 0.0725 at k 3
# Iter: 5129, running avg mse: 0.0844 lowest val mse: 0.0753 at k 3
# Iter: 5130, running avg mse: 0.0817 lowest val mse: 0.0751 at k 3
# Iter: 5131, running avg mse: 0.0855 lowest val mse: 0.0716 at k 3
# Iter: 5132, running avg mse: 0.0845 lowest val mse: 0.0738 at k 3
# Iter: 5133, running avg mse: 0.0806 lowest val mse: 0.0714 at k 3
# Iter: 5134, running avg mse: 0.0820 lowest val mse: 0.0785 at k 3
# Iter: 5135, running avg mse: 0.0860 lowest val mse: 0.0748 at k 3
# Iter: 5136, running avg mse: 0.0837 lowest val mse: 0.0799 at k 3
# Iter: 5137, running avg mse: 0.0793 lowest val mse: 0.0753 at k 3
# Iter: 5138, running avg mse: 0.0784 lowest val mse: 0.0675 at k 3
# Iter: 5139, running avg mse: 0.0830 lowest val mse: 0.0678 at k 3
# Iter: 5140, running avg mse: 0.0814 lowest val mse: 0.0763 at k 3
# Iter: 5141, running avg mse: 0.0833 lowest val mse: 0.0755 at k 3
# Iter: 5142, running avg mse: 0.0809 lowest val mse: 0.0766 at k 3
# Iter: 5143, running avg mse: 0.0827 lowest val mse: 0.0774 at k 3
# Iter: 5144, running avg mse: 0.0833 lowest val mse: 0.0765 at k 3
# Iter: 5145, running avg mse: 0.0856 lowest val mse: 0.0713 at k 3
# Iter: 5146, running avg mse: 0.0806 lowest val mse: 0.0738 at k 3
# Iter: 5147, running avg mse: 0.0809 lowest val mse: 0.0714 at k 2
# Iter: 5148, running avg mse: 0.0810 lowest val mse: 0.0800 at k 3
# Iter: 5149, running avg mse: 0.0813 lowest val mse: 0.0759 at k 3
# Iter: 5150, running avg mse: 0.0852 lowest val mse: 0.0749 at k 3
# Iter: 5151, running avg mse: 0.0839 lowest val mse: 0.0779 at k 3
# Iter: 5152, running avg mse: 0.0827 lowest val mse: 0.0757 at k 3
# Iter: 5153, running avg mse: 0.0836 lowest val mse: 0.0716 at k 3
# Iter: 5154, running avg mse: 0.0844 lowest val mse: 0.0771 at k 3
# Iter: 5155, running avg mse: 0.0805 lowest val mse: 0.0759 at k 3
# Iter: 5156, running avg mse: 0.0815 lowest val mse: 0.0701 at k 3
# Iter: 5157, running avg mse: 0.0833 lowest val mse: 0.0709 at k 2
# Iter: 5158, running avg mse: 0.0797 lowest val mse: 0.0731 at k 3
# Iter: 5159, running avg mse: 0.0820 lowest val mse: 0.0759 at k 3
# Iter: 5160, running avg mse: 0.0832 lowest val mse: 0.0705 at k 3
# Iter: 5161, running avg mse: 0.0818 lowest val mse: 0.0677 at k 3
# Iter: 5162, running avg mse: 0.0822 lowest val mse: 0.0772 at k 3
# Iter: 5163, running avg mse: 0.0781 lowest val mse: 0.0726 at k 3
# Iter: 5164, running avg mse: 0.0802 lowest val mse: 0.0725 at k 3
# Iter: 5165, running avg mse: 0.0851 lowest val mse: 0.0779 at k 3
# Iter: 5166, running avg mse: 0.0789 lowest val mse: 0.0715 at k 3
# Iter: 5167, running avg mse: 0.0834 lowest val mse: 0.0788 at k 3
# Iter: 5168, running avg mse: 0.0872 lowest val mse: 0.0753 at k 3
# Iter: 5169, running avg mse: 0.0783 lowest val mse: 0.0803 at k 3
# Iter: 5170, running avg mse: 0.0888 lowest val mse: 0.0763 at k 3
# Iter: 5171, running avg mse: 0.0792 lowest val mse: 0.0721 at k 3
# Iter: 5172, running avg mse: 0.0901 lowest val mse: 0.0757 at k 3
# Iter: 5173, running avg mse: 0.0971 lowest val mse: 0.0966 at k 3
# Iter: 5174, running avg mse: 0.0863 lowest val mse: 0.0807 at k 3
# Iter: 5175, running avg mse: 0.0830 lowest val mse: 0.0832 at k 3
# Iter: 5176, running avg mse: 0.0925 lowest val mse: 0.0866 at k 3
# Iter: 5177, running avg mse: 0.0911 lowest val mse: 0.0804 at k 3
# Iter: 5178, running avg mse: 0.0886 lowest val mse: 0.0856 at k 3
# Iter: 5179, running avg mse: 0.0969 lowest val mse: 0.0951 at k 3
# Iter: 5180, running avg mse: 0.0937 lowest val mse: 0.0832 at k 3
# Iter: 5181, running avg mse: 0.1137 lowest val mse: 0.0860 at k 3
# Iter: 5182, running avg mse: 0.1192 lowest val mse: 0.0922 at k 3
# Iter: 5183, running avg mse: 0.1248 lowest val mse: 0.1167 at k 3
# Iter: 5184, running avg mse: 0.0924 lowest val mse: 0.0956 at k 3
# Iter: 5185, running avg mse: 0.0867 lowest val mse: 0.0903 at k 3
# Iter: 5186, running avg mse: 0.1068 lowest val mse: 0.0832 at k 3
# Iter: 5187, running avg mse: 0.1020 lowest val mse: 0.0855 at k 3
# Iter: 5188, running avg mse: 0.0915 lowest val mse: 0.0782 at k 3
# Iter: 5189, running avg mse: 0.0917 lowest val mse: 0.0760 at k 3
# Iter: 5190, running avg mse: 0.0836 lowest val mse: 0.0780 at k 3
# Iter: 5191, running avg mse: 0.0880 lowest val mse: 0.0782 at k 3
# Iter: 5192, running avg mse: 0.0864 lowest val mse: 0.0788 at k 3
# Iter: 5193, running avg mse: 0.0875 lowest val mse: 0.0768 at k 3
# Iter: 5194, running avg mse: 0.0887 lowest val mse: 0.0715 at k 3
# Iter: 5195, running avg mse: 0.0855 lowest val mse: 0.0760 at k 3
# Iter: 5196, running avg mse: 0.0910 lowest val mse: 0.0775 at k 3
# Iter: 5197, running avg mse: 0.0805 lowest val mse: 0.0746 at k 3
# Iter: 5198, running avg mse: 0.0847 lowest val mse: 0.0787 at k 3
# Iter: 5199, running avg mse: 0.0828 lowest val mse: 0.0866 at k 3
# Iter: 5200, running avg mse: 0.0810 lowest val mse: 0.0704 at k 3
# Iter: 5201, running avg mse: 0.0844 lowest val mse: 0.0740 at k 3
# Iter: 5202, running avg mse: 0.0886 lowest val mse: 0.0828 at k 3
# Iter: 5203, running avg mse: 0.0879 lowest val mse: 0.0825 at k 3
# Iter: 5204, running avg mse: 0.0974 lowest val mse: 0.0764 at k 3
# Iter: 5205, running avg mse: 0.0960 lowest val mse: 0.0801 at k 3
# Iter: 5206, running avg mse: 0.0918 lowest val mse: 0.0820 at k 2
# Iter: 5207, running avg mse: 0.0877 lowest val mse: 0.0782 at k 3
# Iter: 5208, running avg mse: 0.0862 lowest val mse: 0.0793 at k 3
# Iter: 5209, running avg mse: 0.0918 lowest val mse: 0.0810 at k 3
# Iter: 5210, running avg mse: 0.0932 lowest val mse: 0.0912 at k 3
# Iter: 5211, running avg mse: 0.0808 lowest val mse: 0.0800 at k 3
# Iter: 5212, running avg mse: 0.0890 lowest val mse: 0.0809 at k 3
# Iter: 5213, running avg mse: 0.0845 lowest val mse: 0.0703 at k 3
# Iter: 5214, running avg mse: 0.0838 lowest val mse: 0.0827 at k 3
# Iter: 5215, running avg mse: 0.0857 lowest val mse: 0.0758 at k 3
# Iter: 5216, running avg mse: 0.0856 lowest val mse: 0.0768 at k 3
# Iter: 5217, running avg mse: 0.0867 lowest val mse: 0.0730 at k 3
# Iter: 5218, running avg mse: 0.0918 lowest val mse: 0.0790 at k 2
# Iter: 5219, running avg mse: 0.0815 lowest val mse: 0.0876 at k 3
# Iter: 5220, running avg mse: 0.0807 lowest val mse: 0.0804 at k 3
# Iter: 5221, running avg mse: 0.0827 lowest val mse: 0.0780 at k 3
# Iter: 5222, running avg mse: 0.0847 lowest val mse: 0.0778 at k 3
# Iter: 5223, running avg mse: 0.0883 lowest val mse: 0.0759 at k 3
# Iter: 5224, running avg mse: 0.0909 lowest val mse: 0.0835 at k 3
# Iter: 5225, running avg mse: 0.0892 lowest val mse: 0.0904 at k 3
# Iter: 5226, running avg mse: 0.0860 lowest val mse: 0.0806 at k 3
# Iter: 5227, running avg mse: 0.0944 lowest val mse: 0.0786 at k 3
# Iter: 5228, running avg mse: 0.0990 lowest val mse: 0.0767 at k 3
# Iter: 5229, running avg mse: 0.1006 lowest val mse: 0.0796 at k 3
# Iter: 5230, running avg mse: 0.1019 lowest val mse: 0.0877 at k 3
# Iter: 5231, running avg mse: 0.1040 lowest val mse: 0.0911 at k 4
# Iter: 5232, running avg mse: 0.0954 lowest val mse: 0.0954 at k 3
# Iter: 5233, running avg mse: 0.0837 lowest val mse: 0.0842 at k 4
# Iter: 5234, running avg mse: 0.0942 lowest val mse: 0.0827 at k 3
# Iter: 5235, running avg mse: 0.0992 lowest val mse: 0.0730 at k 3
# Iter: 5236, running avg mse: 0.0959 lowest val mse: 0.0710 at k 3
# Iter: 5237, running avg mse: 0.0856 lowest val mse: 0.0832 at k 3
# Iter: 5238, running avg mse: 0.0866 lowest val mse: 0.0813 at k 3
# Iter: 5239, running avg mse: 0.0924 lowest val mse: 0.0816 at k 3
# Iter: 5240, running avg mse: 0.0832 lowest val mse: 0.0775 at k 3
# Iter: 5241, running avg mse: 0.0886 lowest val mse: 0.0802 at k 3
# Iter: 5242, running avg mse: 0.0832 lowest val mse: 0.0744 at k 3
# Iter: 5243, running avg mse: 0.0818 lowest val mse: 0.0717 at k 2
# Iter: 5244, running avg mse: 0.0815 lowest val mse: 0.0782 at k 3
# Iter: 5245, running avg mse: 0.0849 lowest val mse: 0.0748 at k 3
# Iter: 5246, running avg mse: 0.0857 lowest val mse: 0.0791 at k 3
# Iter: 5247, running avg mse: 0.0831 lowest val mse: 0.0764 at k 3
# Iter: 5248, running avg mse: 0.0958 lowest val mse: 0.0746 at k 3
# Iter: 5249, running avg mse: 0.1020 lowest val mse: 0.0922 at k 3
# Iter: 5250, running avg mse: 0.0912 lowest val mse: 0.0925 at k 3
# Iter: 5251, running avg mse: 0.0847 lowest val mse: 0.0808 at k 3
# Iter: 5252, running avg mse: 0.0857 lowest val mse: 0.0796 at k 3
# Iter: 5253, running avg mse: 0.0901 lowest val mse: 0.0769 at k 3
# Iter: 5254, running avg mse: 0.0826 lowest val mse: 0.0851 at k 3
# Iter: 5255, running avg mse: 0.0839 lowest val mse: 0.0771 at k 3
# Iter: 5256, running avg mse: 0.0919 lowest val mse: 0.0743 at k 3
# Iter: 5257, running avg mse: 0.0937 lowest val mse: 0.0850 at k 3
# Iter: 5258, running avg mse: 0.0904 lowest val mse: 0.0759 at k 3
# Iter: 5259, running avg mse: 0.0856 lowest val mse: 0.0751 at k 3
# Iter: 5260, running avg mse: 0.1044 lowest val mse: 0.0789 at k 3
# Iter: 5261, running avg mse: 0.0900 lowest val mse: 0.0827 at k 3
# Iter: 5262, running avg mse: 0.0894 lowest val mse: 0.0773 at k 2
# Iter: 5263, running avg mse: 0.0834 lowest val mse: 0.0761 at k 3
# Iter: 5264, running avg mse: 0.0896 lowest val mse: 0.0762 at k 3
# Iter: 5265, running avg mse: 0.0886 lowest val mse: 0.0781 at k 3
# Iter: 5266, running avg mse: 0.0769 lowest val mse: 0.0783 at k 3
# Iter: 5267, running avg mse: 0.0848 lowest val mse: 0.0759 at k 3
# Iter: 5268, running avg mse: 0.0785 lowest val mse: 0.0752 at k 2
# Iter: 5269, running avg mse: 0.0852 lowest val mse: 0.0810 at k 3
# Iter: 5270, running avg mse: 0.0821 lowest val mse: 0.0741 at k 3
# Iter: 5271, running avg mse: 0.0850 lowest val mse: 0.0759 at k 3
# Iter: 5272, running avg mse: 0.0842 lowest val mse: 0.0678 at k 3
# Iter: 5273, running avg mse: 0.0924 lowest val mse: 0.0795 at k 3
# Iter: 5274, running avg mse: 0.0904 lowest val mse: 0.0926 at k 3
# Iter: 5275, running avg mse: 0.0851 lowest val mse: 0.0805 at k 3
# Iter: 5276, running avg mse: 0.0838 lowest val mse: 0.0772 at k 3
# Iter: 5277, running avg mse: 0.0992 lowest val mse: 0.0948 at k 3
# Iter: 5278, running avg mse: 0.0849 lowest val mse: 0.0815 at k 3
# Iter: 5279, running avg mse: 0.0887 lowest val mse: 0.0782 at k 3
# Iter: 5280, running avg mse: 0.0966 lowest val mse: 0.0911 at k 3
# Iter: 5281, running avg mse: 0.0923 lowest val mse: 0.0850 at k 3
# Iter: 5282, running avg mse: 0.0861 lowest val mse: 0.0739 at k 3
# Iter: 5283, running avg mse: 0.0879 lowest val mse: 0.0726 at k 3
# Iter: 5284, running avg mse: 0.1046 lowest val mse: 0.0846 at k 3
# Iter: 5285, running avg mse: 0.0958 lowest val mse: 0.1034 at k 3
# Iter: 5286, running avg mse: 0.0987 lowest val mse: 0.0988 at k 3
# Iter: 5287, running avg mse: 0.0912 lowest val mse: 0.1084 at k 3
# Iter: 5288, running avg mse: 0.0978 lowest val mse: 0.0912 at k 3
# Iter: 5289, running avg mse: 0.1040 lowest val mse: 0.0792 at k 3
# Iter: 5290, running avg mse: 0.1085 lowest val mse: 0.0851 at k 3
# Iter: 5291, running avg mse: 0.1117 lowest val mse: 0.0831 at k 3
# Iter: 5292, running avg mse: 0.1080 lowest val mse: 0.0810 at k 3
# Iter: 5293, running avg mse: 0.0985 lowest val mse: 0.0768 at k 3
# Iter: 5294, running avg mse: 0.0921 lowest val mse: 0.0919 at k 2
# Iter: 5295, running avg mse: 0.0931 lowest val mse: 0.0951 at k 2
# Iter: 5296, running avg mse: 0.0970 lowest val mse: 0.0785 at k 3
# Iter: 5297, running avg mse: 0.0945 lowest val mse: 0.0852 at k 3
# Iter: 5298, running avg mse: 0.0880 lowest val mse: 0.0752 at k 3
# Iter: 5299, running avg mse: 0.0855 lowest val mse: 0.0839 at k 3
# Iter: 5300, running avg mse: 0.0835 lowest val mse: 0.0821 at k 4
# Iter: 5301, running avg mse: 0.0883 lowest val mse: 0.0774 at k 3
# Iter: 5302, running avg mse: 0.0848 lowest val mse: 0.0795 at k 2
# Iter: 5303, running avg mse: 0.0820 lowest val mse: 0.0801 at k 3
# Iter: 5304, running avg mse: 0.0836 lowest val mse: 0.0703 at k 3
# Iter: 5305, running avg mse: 0.0852 lowest val mse: 0.0701 at k 3
# Iter: 5306, running avg mse: 0.0812 lowest val mse: 0.0805 at k 3
# Iter: 5307, running avg mse: 0.0872 lowest val mse: 0.0868 at k 3
# Iter: 5308, running avg mse: 0.0810 lowest val mse: 0.0744 at k 3
# Iter: 5309, running avg mse: 0.0805 lowest val mse: 0.0758 at k 3
# Iter: 5310, running avg mse: 0.0802 lowest val mse: 0.0741 at k 3
# Iter: 5311, running avg mse: 0.0844 lowest val mse: 0.0750 at k 3
# Iter: 5312, running avg mse: 0.0784 lowest val mse: 0.0751 at k 3
# Iter: 5313, running avg mse: 0.0808 lowest val mse: 0.0799 at k 3
# Iter: 5314, running avg mse: 0.0898 lowest val mse: 0.0773 at k 3
# Iter: 5315, running avg mse: 0.0867 lowest val mse: 0.0790 at k 3
# Iter: 5316, running avg mse: 0.0857 lowest val mse: 0.0770 at k 3
# Iter: 5317, running avg mse: 0.0819 lowest val mse: 0.0813 at k 3
# Iter: 5318, running avg mse: 0.0862 lowest val mse: 0.0717 at k 3
# Iter: 5319, running avg mse: 0.0836 lowest val mse: 0.0852 at k 3
# Iter: 5320, running avg mse: 0.0884 lowest val mse: 0.0700 at k 3
# Iter: 5321, running avg mse: 0.0810 lowest val mse: 0.0749 at k 3
# Iter: 5322, running avg mse: 0.0804 lowest val mse: 0.0786 at k 3
# Iter: 5323, running avg mse: 0.0790 lowest val mse: 0.0778 at k 3
# Iter: 5324, running avg mse: 0.0754 lowest val mse: 0.0656 at k 3
# Iter: 5325, running avg mse: 0.0805 lowest val mse: 0.0755 at k 3
# Iter: 5326, running avg mse: 0.0789 lowest val mse: 0.0656 at k 3
# Iter: 5327, running avg mse: 0.0797 lowest val mse: 0.0715 at k 3
# Iter: 5328, running avg mse: 0.0792 lowest val mse: 0.0730 at k 3
# Iter: 5329, running avg mse: 0.0791 lowest val mse: 0.0701 at k 3
# Iter: 5330, running avg mse: 0.0790 lowest val mse: 0.0727 at k 3
# Iter: 5331, running avg mse: 0.0785 lowest val mse: 0.0758 at k 3
# Iter: 5332, running avg mse: 0.0808 lowest val mse: 0.0770 at k 3
# Iter: 5333, running avg mse: 0.0792 lowest val mse: 0.0744 at k 3
# Iter: 5334, running avg mse: 0.0805 lowest val mse: 0.0720 at k 3
# Iter: 5335, running avg mse: 0.0824 lowest val mse: 0.0730 at k 3
# Iter: 5336, running avg mse: 0.0825 lowest val mse: 0.0705 at k 3
# Iter: 5337, running avg mse: 0.0805 lowest val mse: 0.0702 at k 3
# Iter: 5338, running avg mse: 0.0796 lowest val mse: 0.0761 at k 3
# Iter: 5339, running avg mse: 0.0789 lowest val mse: 0.0710 at k 3
# Iter: 5340, running avg mse: 0.0812 lowest val mse: 0.0694 at k 3
# Iter: 5341, running avg mse: 0.0806 lowest val mse: 0.0739 at k 3
# Iter: 5342, running avg mse: 0.0827 lowest val mse: 0.0686 at k 2
# Iter: 5343, running avg mse: 0.0888 lowest val mse: 0.0744 at k 3
# Iter: 5344, running avg mse: 0.0838 lowest val mse: 0.0849 at k 3
# Iter: 5345, running avg mse: 0.0966 lowest val mse: 0.0773 at k 3
# Iter: 5346, running avg mse: 0.0916 lowest val mse: 0.0833 at k 3
# Iter: 5347, running avg mse: 0.0858 lowest val mse: 0.0780 at k 3
# Iter: 5348, running avg mse: 0.0936 lowest val mse: 0.0803 at k 3
# Iter: 5349, running avg mse: 0.0989 lowest val mse: 0.1037 at k 3
# Iter: 5350, running avg mse: 0.0862 lowest val mse: 0.0815 at k 3
# Iter: 5351, running avg mse: 0.0896 lowest val mse: 0.0823 at k 3
# Iter: 5352, running avg mse: 0.1230 lowest val mse: 0.0893 at k 4
# Iter: 5353, running avg mse: 0.1150 lowest val mse: 0.1005 at k 3
# Iter: 5354, running avg mse: 0.0902 lowest val mse: 0.0904 at k 3
# Iter: 5355, running avg mse: 0.0917 lowest val mse: 0.0815 at k 3
# Iter: 5356, running avg mse: 0.0898 lowest val mse: 0.0841 at k 3
# Iter: 5357, running avg mse: 0.0828 lowest val mse: 0.0871 at k 3
# Iter: 5358, running avg mse: 0.0892 lowest val mse: 0.0780 at k 3
# Iter: 5359, running avg mse: 0.0908 lowest val mse: 0.0855 at k 4
# Iter: 5360, running avg mse: 0.0833 lowest val mse: 0.0849 at k 3
# Iter: 5361, running avg mse: 0.0914 lowest val mse: 0.0800 at k 3
# Iter: 5362, running avg mse: 0.0931 lowest val mse: 0.0904 at k 4
# Iter: 5363, running avg mse: 0.0843 lowest val mse: 0.0804 at k 3
# Iter: 5364, running avg mse: 0.0897 lowest val mse: 0.0743 at k 3
# Iter: 5365, running avg mse: 0.0873 lowest val mse: 0.0827 at k 3
# Iter: 5366, running avg mse: 0.0943 lowest val mse: 0.1035 at k 2
# Iter: 5367, running avg mse: 0.0974 lowest val mse: 0.0943 at k 3
# Iter: 5368, running avg mse: 0.0938 lowest val mse: 0.0813 at k 3
# Iter: 5369, running avg mse: 0.1077 lowest val mse: 0.1137 at k 3
# Iter: 5370, running avg mse: 0.0895 lowest val mse: 0.0860 at k 3
# Iter: 5371, running avg mse: 0.0887 lowest val mse: 0.0811 at k 3
# Iter: 5372, running avg mse: 0.1130 lowest val mse: 0.0863 at k 3
# Iter: 5373, running avg mse: 0.1300 lowest val mse: 0.0882 at k 3
# Iter: 5374, running avg mse: 0.1538 lowest val mse: 0.1094 at k 3
# Iter: 5375, running avg mse: 0.1175 lowest val mse: 0.0849 at k 3
# Iter: 5376, running avg mse: 0.0900 lowest val mse: 0.0817 at k 3
# Iter: 5377, running avg mse: 0.0981 lowest val mse: 0.0853 at k 3
# Iter: 5378, running avg mse: 0.0925 lowest val mse: 0.0763 at k 3
# Iter: 5379, running avg mse: 0.0902 lowest val mse: 0.0749 at k 3
# Iter: 5380, running avg mse: 0.0918 lowest val mse: 0.0844 at k 3
# Iter: 5381, running avg mse: 0.0910 lowest val mse: 0.0823 at k 3
# Iter: 5382, running avg mse: 0.0917 lowest val mse: 0.0804 at k 3
# Iter: 5383, running avg mse: 0.0965 lowest val mse: 0.0877 at k 4
# Iter: 5384, running avg mse: 0.0860 lowest val mse: 0.0750 at k 3
# Iter: 5385, running avg mse: 0.0856 lowest val mse: 0.0832 at k 3
# Iter: 5386, running avg mse: 0.0876 lowest val mse: 0.0741 at k 3
# Iter: 5387, running avg mse: 0.0896 lowest val mse: 0.0879 at k 3
# Iter: 5388, running avg mse: 0.0838 lowest val mse: 0.0796 at k 3
# Iter: 5389, running avg mse: 0.0817 lowest val mse: 0.0795 at k 3
# Iter: 5390, running avg mse: 0.0865 lowest val mse: 0.0818 at k 3
# Iter: 5391, running avg mse: 0.0959 lowest val mse: 0.0748 at k 3
# Iter: 5392, running avg mse: 0.0831 lowest val mse: 0.0755 at k 3
# Iter: 5393, running avg mse: 0.0898 lowest val mse: 0.0792 at k 3
# Iter: 5394, running avg mse: 0.0827 lowest val mse: 0.0805 at k 3
# Iter: 5395, running avg mse: 0.0804 lowest val mse: 0.0741 at k 3
# Iter: 5396, running avg mse: 0.0838 lowest val mse: 0.0714 at k 3
# Iter: 5397, running avg mse: 0.0864 lowest val mse: 0.0822 at k 3
# Iter: 5398, running avg mse: 0.0964 lowest val mse: 0.0842 at k 3
# Iter: 5399, running avg mse: 0.1420 lowest val mse: 0.1086 at k 3
# Iter: 5400, running avg mse: 0.2150 lowest val mse: 0.1543 at k 4
# Iter: 5401, running avg mse: 0.2305 lowest val mse: 0.1945 at k 4
# Iter: 5402, running avg mse: 0.2684 lowest val mse: 0.2009 at k 4
# Iter: 5403, running avg mse: 0.2887 lowest val mse: 0.2342 at k 4
# Iter: 5404, running avg mse: 0.2873 lowest val mse: 0.3255 at k 5
# Iter: 5405, running avg mse: 0.2207 lowest val mse: 0.2587 at k 3
# Iter: 5406, running avg mse: 0.2751 lowest val mse: 0.2420 at k 4
# Iter: 5407, running avg mse: 0.2505 lowest val mse: 0.2245 at k 4
# Iter: 5408, running avg mse: 0.2456 lowest val mse: 0.2513 at k 4
# Iter: 5409, running avg mse: 0.2280 lowest val mse: 0.3249 at k 4
# Iter: 5410, running avg mse: 0.2779 lowest val mse: 0.2664 at k 5
# Iter: 5411, running avg mse: 0.3433 lowest val mse: 0.2099 at k 5
# Iter: 5412, running avg mse: 0.2169 lowest val mse: 0.2108 at k 5
# Iter: 5413, running avg mse: 0.2632 lowest val mse: 0.2749 at k 3
# Iter: 5414, running avg mse: 0.2105 lowest val mse: 0.2591 at k 5
# Iter: 5415, running avg mse: 0.2857 lowest val mse: 0.1870 at k 4
# Iter: 5416, running avg mse: 0.2268 lowest val mse: 0.1777 at k 4
# Iter: 5417, running avg mse: 0.2678 lowest val mse: 0.2714 at k 4
# Iter: 5418, running avg mse: 0.2396 lowest val mse: 0.2080 at k 3
# Iter: 5419, running avg mse: 0.2527 lowest val mse: 0.1734 at k 3
# Iter: 5420, running avg mse: 0.1703 lowest val mse: 0.1845 at k 3
# Iter: 5421, running avg mse: 0.2037 lowest val mse: 0.1521 at k 3
# Iter: 5422, running avg mse: 0.1586 lowest val mse: 0.1708 at k 3
# Iter: 5423, running avg mse: 0.1804 lowest val mse: 0.1566 at k 2
# Iter: 5424, running avg mse: 0.1545 lowest val mse: 0.1575 at k 4
# Iter: 5425, running avg mse: 0.1703 lowest val mse: 0.1532 at k 2
# Iter: 5426, running avg mse: 0.1664 lowest val mse: 0.1651 at k 3
# Iter: 5427, running avg mse: 0.1595 lowest val mse: 0.1353 at k 3
# Iter: 5428, running avg mse: 0.1487 lowest val mse: 0.1375 at k 4
# Iter: 5429, running avg mse: 0.1471 lowest val mse: 0.1211 at k 3
# Iter: 5430, running avg mse: 0.1442 lowest val mse: 0.1226 at k 3
# Iter: 5431, running avg mse: 0.1585 lowest val mse: 0.1285 at k 3
# Iter: 5432, running avg mse: 0.1331 lowest val mse: 0.1135 at k 3
# Iter: 5433, running avg mse: 0.1300 lowest val mse: 0.1145 at k 3
# Iter: 5434, running avg mse: 0.1197 lowest val mse: 0.1112 at k 3
# Iter: 5435, running avg mse: 0.1179 lowest val mse: 0.1086 at k 3
# Iter: 5436, running avg mse: 0.1103 lowest val mse: 0.0955 at k 3
# Iter: 5437, running avg mse: 0.1296 lowest val mse: 0.1170 at k 1
# Iter: 5438, running avg mse: 0.1169 lowest val mse: 0.1415 at k 3
# Iter: 5439, running avg mse: 0.1330 lowest val mse: 0.1314 at k 3
# Iter: 5440, running avg mse: 0.1271 lowest val mse: 0.1110 at k 3
# Iter: 5441, running avg mse: 0.1217 lowest val mse: 0.1085 at k 3
# Iter: 5442, running avg mse: 0.1219 lowest val mse: 0.1183 at k 3
# Iter: 5443, running avg mse: 0.1196 lowest val mse: 0.1304 at k 3
# Iter: 5444, running avg mse: 0.1210 lowest val mse: 0.1367 at k 3
# Iter: 5445, running avg mse: 0.1429 lowest val mse: 0.1291 at k 3
# Iter: 5446, running avg mse: 0.1631 lowest val mse: 0.1115 at k 4
# Iter: 5447, running avg mse: 0.1276 lowest val mse: 0.1082 at k 3
# Iter: 5448, running avg mse: 0.1162 lowest val mse: 0.1145 at k 3
# Iter: 5449, running avg mse: 0.1138 lowest val mse: 0.1137 at k 3
# Iter: 5450, running avg mse: 0.1167 lowest val mse: 0.1186 at k 3
# Iter: 5451, running avg mse: 0.1082 lowest val mse: 0.1003 at k 3
# Iter: 5452, running avg mse: 0.1138 lowest val mse: 0.0988 at k 3
# Iter: 5453, running avg mse: 0.0985 lowest val mse: 0.0951 at k 3
# Iter: 5454, running avg mse: 0.1070 lowest val mse: 0.0902 at k 3
# Iter: 5455, running avg mse: 0.1066 lowest val mse: 0.0860 at k 3
# Iter: 5456, running avg mse: 0.0967 lowest val mse: 0.0876 at k 3
# Iter: 5457, running avg mse: 0.1020 lowest val mse: 0.0872 at k 3
# Iter: 5458, running avg mse: 0.0897 lowest val mse: 0.0833 at k 3
# Iter: 5459, running avg mse: 0.0935 lowest val mse: 0.0873 at k 3
# Iter: 5460, running avg mse: 0.0970 lowest val mse: 0.0825 at k 3
# Iter: 5461, running avg mse: 0.0960 lowest val mse: 0.0866 at k 3
# Iter: 5462, running avg mse: 0.0943 lowest val mse: 0.0880 at k 3
# Iter: 5463, running avg mse: 0.0925 lowest val mse: 0.0791 at k 2
# Iter: 5464, running avg mse: 0.0980 lowest val mse: 0.0940 at k 3
# Iter: 5465, running avg mse: 0.0958 lowest val mse: 0.0863 at k 3
# Iter: 5466, running avg mse: 0.0909 lowest val mse: 0.0881 at k 3
# Iter: 5467, running avg mse: 0.1002 lowest val mse: 0.0871 at k 3
# Iter: 5468, running avg mse: 0.0969 lowest val mse: 0.0879 at k 3
# Iter: 5469, running avg mse: 0.1013 lowest val mse: 0.0948 at k 3
# Iter: 5470, running avg mse: 0.0998 lowest val mse: 0.0830 at k 3
# Iter: 5471, running avg mse: 0.0971 lowest val mse: 0.0856 at k 3
# Iter: 5472, running avg mse: 0.0950 lowest val mse: 0.0879 at k 3
# Iter: 5473, running avg mse: 0.0896 lowest val mse: 0.0874 at k 3
# Iter: 5474, running avg mse: 0.0862 lowest val mse: 0.0873 at k 3
# Iter: 5475, running avg mse: 0.0915 lowest val mse: 0.0787 at k 3
# Iter: 5476, running avg mse: 0.0872 lowest val mse: 0.0867 at k 3
# Iter: 5477, running avg mse: 0.0892 lowest val mse: 0.0855 at k 3
# Iter: 5478, running avg mse: 0.0903 lowest val mse: 0.0826 at k 3
# Iter: 5479, running avg mse: 0.0878 lowest val mse: 0.0838 at k 3
# Iter: 5480, running avg mse: 0.0907 lowest val mse: 0.0751 at k 3
# Iter: 5481, running avg mse: 0.0889 lowest val mse: 0.0796 at k 2
# Iter: 5482, running avg mse: 0.0915 lowest val mse: 0.0791 at k 3
# Iter: 5483, running avg mse: 0.0898 lowest val mse: 0.0854 at k 3
# Iter: 5484, running avg mse: 0.0880 lowest val mse: 0.0816 at k 2
# Iter: 5485, running avg mse: 0.0932 lowest val mse: 0.0934 at k 3
# Iter: 5486, running avg mse: 0.0882 lowest val mse: 0.0752 at k 3
# Iter: 5487, running avg mse: 0.0914 lowest val mse: 0.0790 at k 3
# Iter: 5488, running avg mse: 0.0985 lowest val mse: 0.0876 at k 3
# Iter: 5489, running avg mse: 0.0868 lowest val mse: 0.0832 at k 3
# Iter: 5490, running avg mse: 0.0873 lowest val mse: 0.0845 at k 3
# Iter: 5491, running avg mse: 0.0885 lowest val mse: 0.0800 at k 3
# Iter: 5492, running avg mse: 0.0958 lowest val mse: 0.0749 at k 3
# Iter: 5493, running avg mse: 0.0989 lowest val mse: 0.0878 at k 3
# Iter: 5494, running avg mse: 0.0943 lowest val mse: 0.0822 at k 2
# Iter: 5495, running avg mse: 0.0854 lowest val mse: 0.0831 at k 2
# Iter: 5496, running avg mse: 0.0851 lowest val mse: 0.0754 at k 3
# Iter: 5497, running avg mse: 0.0872 lowest val mse: 0.0825 at k 3
# Iter: 5498, running avg mse: 0.0883 lowest val mse: 0.0710 at k 3
# Iter: 5499, running avg mse: 0.0839 lowest val mse: 0.0789 at k 3
# Iter: 5500, running avg mse: 0.0891 lowest val mse: 0.0791 at k 3
# Iter: 5501, running avg mse: 0.0869 lowest val mse: 0.0851 at k 3
# Iter: 5502, running avg mse: 0.0829 lowest val mse: 0.0816 at k 3
# Iter: 5503, running avg mse: 0.0800 lowest val mse: 0.0821 at k 3
# Iter: 5504, running avg mse: 0.0876 lowest val mse: 0.0768 at k 2
# Iter: 5505, running avg mse: 0.0901 lowest val mse: 0.0802 at k 3
# Iter: 5506, running avg mse: 0.0939 lowest val mse: 0.0836 at k 3
# Iter: 5507, running avg mse: 0.0853 lowest val mse: 0.0716 at k 3
# Iter: 5508, running avg mse: 0.0883 lowest val mse: 0.0797 at k 3
# Iter: 5509, running avg mse: 0.0862 lowest val mse: 0.0806 at k 3
# Iter: 5510, running avg mse: 0.0810 lowest val mse: 0.0827 at k 3
# Iter: 5511, running avg mse: 0.0868 lowest val mse: 0.0762 at k 3
# Iter: 5512, running avg mse: 0.0910 lowest val mse: 0.0765 at k 3
# Iter: 5513, running avg mse: 0.0871 lowest val mse: 0.0850 at k 3
# Iter: 5514, running avg mse: 0.0865 lowest val mse: 0.0733 at k 3
# Iter: 5515, running avg mse: 0.0911 lowest val mse: 0.0815 at k 3
# Iter: 5516, running avg mse: 0.0938 lowest val mse: 0.0764 at k 3
# Iter: 5517, running avg mse: 0.0858 lowest val mse: 0.0829 at k 2
# Iter: 5518, running avg mse: 0.0837 lowest val mse: 0.0715 at k 3
# Iter: 5519, running avg mse: 0.0916 lowest val mse: 0.0798 at k 3
# Iter: 5520, running avg mse: 0.0950 lowest val mse: 0.0823 at k 3
# Iter: 5521, running avg mse: 0.0868 lowest val mse: 0.0964 at k 3
# Iter: 5522, running avg mse: 0.0922 lowest val mse: 0.0803 at k 3
# Iter: 5523, running avg mse: 0.0959 lowest val mse: 0.0812 at k 2
# Iter: 5524, running avg mse: 0.0879 lowest val mse: 0.0790 at k 3
# Iter: 5525, running avg mse: 0.0928 lowest val mse: 0.0907 at k 3
# Iter: 5526, running avg mse: 0.0871 lowest val mse: 0.0757 at k 3
# Iter: 5527, running avg mse: 0.0979 lowest val mse: 0.0809 at k 3
# Iter: 5528, running avg mse: 0.1015 lowest val mse: 0.0991 at k 3
# Iter: 5529, running avg mse: 0.1076 lowest val mse: 0.1030 at k 3
# Iter: 5530, running avg mse: 0.0969 lowest val mse: 0.0835 at k 3
# Iter: 5531, running avg mse: 0.0930 lowest val mse: 0.0940 at k 2
# Iter: 5532, running avg mse: 0.0997 lowest val mse: 0.0832 at k 4
# Iter: 5533, running avg mse: 0.0980 lowest val mse: 0.0924 at k 3
# Iter: 5534, running avg mse: 0.0964 lowest val mse: 0.0860 at k 2
# Iter: 5535, running avg mse: 0.0959 lowest val mse: 0.0850 at k 3
# Iter: 5536, running avg mse: 0.1014 lowest val mse: 0.0887 at k 3
# Iter: 5537, running avg mse: 0.1016 lowest val mse: 0.0869 at k 3
# Iter: 5538, running avg mse: 0.0955 lowest val mse: 0.0820 at k 3
# Iter: 5539, running avg mse: 0.0966 lowest val mse: 0.1005 at k 3
# Iter: 5540, running avg mse: 0.0939 lowest val mse: 0.0991 at k 3
# Iter: 5541, running avg mse: 0.0970 lowest val mse: 0.0923 at k 3
# Iter: 5542, running avg mse: 0.0891 lowest val mse: 0.0879 at k 3
# Iter: 5543, running avg mse: 0.0946 lowest val mse: 0.0861 at k 3
# Iter: 5544, running avg mse: 0.0910 lowest val mse: 0.0839 at k 3
# Iter: 5545, running avg mse: 0.0891 lowest val mse: 0.0844 at k 2
# Iter: 5546, running avg mse: 0.0883 lowest val mse: 0.0772 at k 3
# Iter: 5547, running avg mse: 0.0868 lowest val mse: 0.0774 at k 2
# Iter: 5548, running avg mse: 0.0878 lowest val mse: 0.0783 at k 3
# Iter: 5549, running avg mse: 0.0889 lowest val mse: 0.0878 at k 3
# Iter: 5550, running avg mse: 0.0854 lowest val mse: 0.0898 at k 3
# Iter: 5551, running avg mse: 0.1009 lowest val mse: 0.0898 at k 3
# Iter: 5552, running avg mse: 0.1075 lowest val mse: 0.0840 at k 3
# Iter: 5553, running avg mse: 0.1092 lowest val mse: 0.0828 at k 3
# Iter: 5554, running avg mse: 0.1111 lowest val mse: 0.0927 at k 3
# Iter: 5555, running avg mse: 0.0955 lowest val mse: 0.1076 at k 3
# Iter: 5556, running avg mse: 0.1037 lowest val mse: 0.0924 at k 3
# Iter: 5557, running avg mse: 0.1133 lowest val mse: 0.1013 at k 3
# Iter: 5558, running avg mse: 0.1197 lowest val mse: 0.1152 at k 3
# Iter: 5559, running avg mse: 0.1364 lowest val mse: 0.1168 at k 4
# Iter: 5560, running avg mse: 0.1283 lowest val mse: 0.0974 at k 3
# Iter: 5561, running avg mse: 0.1098 lowest val mse: 0.0938 at k 3
# Iter: 5562, running avg mse: 0.1086 lowest val mse: 0.0968 at k 3
# Iter: 5563, running avg mse: 0.1048 lowest val mse: 0.1237 at k 3
# Iter: 5564, running avg mse: 0.1323 lowest val mse: 0.1230 at k 4
# Iter: 5565, running avg mse: 0.1486 lowest val mse: 0.0947 at k 3
# Iter: 5566, running avg mse: 0.1009 lowest val mse: 0.1251 at k 3
# Iter: 5567, running avg mse: 0.1388 lowest val mse: 0.1083 at k 4
# Iter: 5568, running avg mse: 0.1099 lowest val mse: 0.0923 at k 3
# Iter: 5569, running avg mse: 0.1034 lowest val mse: 0.1012 at k 3
# Iter: 5570, running avg mse: 0.1030 lowest val mse: 0.0847 at k 3
# Iter: 5571, running avg mse: 0.0964 lowest val mse: 0.0869 at k 3
# Iter: 5572, running avg mse: 0.0978 lowest val mse: 0.0911 at k 3
# Iter: 5573, running avg mse: 0.0955 lowest val mse: 0.0792 at k 3
# Iter: 5574, running avg mse: 0.1004 lowest val mse: 0.0842 at k 3
# Iter: 5575, running avg mse: 0.1028 lowest val mse: 0.0909 at k 3
# Iter: 5576, running avg mse: 0.1012 lowest val mse: 0.0926 at k 3
# Iter: 5577, running avg mse: 0.0941 lowest val mse: 0.0957 at k 3
# Iter: 5578, running avg mse: 0.0976 lowest val mse: 0.0881 at k 3
# Iter: 5579, running avg mse: 0.0910 lowest val mse: 0.0933 at k 3
# Iter: 5580, running avg mse: 0.0924 lowest val mse: 0.0852 at k 3
# Iter: 5581, running avg mse: 0.0988 lowest val mse: 0.0836 at k 3
# Iter: 5582, running avg mse: 0.0968 lowest val mse: 0.0909 at k 3
# Iter: 5583, running avg mse: 0.0884 lowest val mse: 0.0862 at k 3
# Iter: 5584, running avg mse: 0.0867 lowest val mse: 0.0826 at k 3
# Iter: 5585, running avg mse: 0.0948 lowest val mse: 0.0899 at k 2
# Iter: 5586, running avg mse: 0.0898 lowest val mse: 0.0757 at k 3
# Iter: 5587, running avg mse: 0.0837 lowest val mse: 0.0793 at k 3
# Iter: 5588, running avg mse: 0.0871 lowest val mse: 0.0832 at k 3
# Iter: 5589, running avg mse: 0.0833 lowest val mse: 0.0842 at k 3
# Iter: 5590, running avg mse: 0.0920 lowest val mse: 0.0798 at k 3
# Iter: 5591, running avg mse: 0.0867 lowest val mse: 0.0831 at k 4
# Iter: 5592, running avg mse: 0.0893 lowest val mse: 0.0785 at k 3
# Iter: 5593, running avg mse: 0.0868 lowest val mse: 0.0764 at k 3
# Iter: 5594, running avg mse: 0.0884 lowest val mse: 0.0754 at k 3
# Iter: 5595, running avg mse: 0.0875 lowest val mse: 0.0792 at k 3
# Iter: 5596, running avg mse: 0.0816 lowest val mse: 0.0781 at k 3
# Iter: 5597, running avg mse: 0.0860 lowest val mse: 0.0784 at k 3
# Iter: 5598, running avg mse: 0.0859 lowest val mse: 0.0802 at k 3
# Iter: 5599, running avg mse: 0.0852 lowest val mse: 0.0731 at k 3
# Iter: 5600, running avg mse: 0.0879 lowest val mse: 0.0805 at k 3
# Iter: 5601, running avg mse: 0.0867 lowest val mse: 0.0768 at k 2
# Iter: 5602, running avg mse: 0.0866 lowest val mse: 0.0789 at k 3
# Iter: 5603, running avg mse: 0.0893 lowest val mse: 0.0852 at k 3
# Iter: 5604, running avg mse: 0.0854 lowest val mse: 0.0887 at k 3
# Iter: 5605, running avg mse: 0.0864 lowest val mse: 0.0770 at k 3
# Iter: 5606, running avg mse: 0.0835 lowest val mse: 0.0855 at k 3
# Iter: 5607, running avg mse: 0.0812 lowest val mse: 0.0769 at k 3
# Iter: 5608, running avg mse: 0.0831 lowest val mse: 0.0785 at k 3
# Iter: 5609, running avg mse: 0.0800 lowest val mse: 0.0800 at k 3
# Iter: 5610, running avg mse: 0.0811 lowest val mse: 0.0831 at k 3
# Iter: 5611, running avg mse: 0.0864 lowest val mse: 0.0726 at k 3
# Iter: 5612, running avg mse: 0.0866 lowest val mse: 0.0766 at k 3
# Iter: 5613, running avg mse: 0.0841 lowest val mse: 0.0798 at k 3
# Iter: 5614, running avg mse: 0.0903 lowest val mse: 0.0854 at k 3
# Iter: 5615, running avg mse: 0.0847 lowest val mse: 0.0743 at k 3
# Iter: 5616, running avg mse: 0.0867 lowest val mse: 0.0750 at k 3
# Iter: 5617, running avg mse: 0.0862 lowest val mse: 0.0819 at k 3
# Iter: 5618, running avg mse: 0.0998 lowest val mse: 0.0845 at k 3
# Iter: 5619, running avg mse: 0.0839 lowest val mse: 0.0769 at k 3
# Iter: 5620, running avg mse: 0.0871 lowest val mse: 0.0780 at k 3
# Iter: 5621, running avg mse: 0.0800 lowest val mse: 0.0752 at k 2
# Iter: 5622, running avg mse: 0.0803 lowest val mse: 0.0775 at k 3
# Iter: 5623, running avg mse: 0.0852 lowest val mse: 0.0744 at k 3
# Iter: 5624, running avg mse: 0.0850 lowest val mse: 0.0718 at k 3
# Iter: 5625, running avg mse: 0.0814 lowest val mse: 0.0717 at k 3
# Iter: 5626, running avg mse: 0.0802 lowest val mse: 0.0736 at k 3
# Iter: 5627, running avg mse: 0.0892 lowest val mse: 0.0799 at k 3
# Iter: 5628, running avg mse: 0.0876 lowest val mse: 0.0793 at k 3
# Iter: 5629, running avg mse: 0.0827 lowest val mse: 0.0782 at k 3
# Iter: 5630, running avg mse: 0.0841 lowest val mse: 0.0747 at k 3
# Iter: 5631, running avg mse: 0.0842 lowest val mse: 0.0741 at k 2
# Iter: 5632, running avg mse: 0.0825 lowest val mse: 0.0779 at k 3
# Iter: 5633, running avg mse: 0.0820 lowest val mse: 0.0725 at k 3
# Iter: 5634, running avg mse: 0.0845 lowest val mse: 0.0810 at k 3
# Iter: 5635, running avg mse: 0.0866 lowest val mse: 0.0766 at k 3
# Iter: 5636, running avg mse: 0.0847 lowest val mse: 0.0753 at k 3
# Iter: 5637, running avg mse: 0.0847 lowest val mse: 0.0841 at k 3
# Iter: 5638, running avg mse: 0.0857 lowest val mse: 0.0791 at k 3
# Iter: 5639, running avg mse: 0.1052 lowest val mse: 0.0983 at k 3
# Iter: 5640, running avg mse: 0.0968 lowest val mse: 0.0969 at k 3
# Iter: 5641, running avg mse: 0.0910 lowest val mse: 0.0819 at k 2
# Iter: 5642, running avg mse: 0.0944 lowest val mse: 0.0800 at k 3
# Iter: 5643, running avg mse: 0.0884 lowest val mse: 0.0875 at k 3
# Iter: 5644, running avg mse: 0.0871 lowest val mse: 0.0746 at k 3
# Iter: 5645, running avg mse: 0.0824 lowest val mse: 0.0778 at k 3
# Iter: 5646, running avg mse: 0.0833 lowest val mse: 0.0751 at k 4
# Iter: 5647, running avg mse: 0.0862 lowest val mse: 0.0754 at k 3
# Iter: 5648, running avg mse: 0.0846 lowest val mse: 0.0745 at k 3
# Iter: 5649, running avg mse: 0.0828 lowest val mse: 0.0785 at k 3
# Iter: 5650, running avg mse: 0.0799 lowest val mse: 0.0756 at k 3
# Iter: 5651, running avg mse: 0.0854 lowest val mse: 0.0791 at k 3
# Iter: 5652, running avg mse: 0.0896 lowest val mse: 0.0788 at k 3
# Iter: 5653, running avg mse: 0.0859 lowest val mse: 0.0722 at k 3
# Iter: 5654, running avg mse: 0.0861 lowest val mse: 0.0744 at k 3
# Iter: 5655, running avg mse: 0.0873 lowest val mse: 0.0806 at k 3
# Iter: 5656, running avg mse: 0.0785 lowest val mse: 0.0786 at k 3
# Iter: 5657, running avg mse: 0.0865 lowest val mse: 0.0776 at k 3
# Iter: 5658, running avg mse: 0.0864 lowest val mse: 0.0809 at k 3
# Iter: 5659, running avg mse: 0.0840 lowest val mse: 0.0856 at k 3
# Iter: 5660, running avg mse: 0.0864 lowest val mse: 0.0737 at k 3
# Iter: 5661, running avg mse: 0.0803 lowest val mse: 0.0803 at k 3
# Iter: 5662, running avg mse: 0.0821 lowest val mse: 0.0801 at k 3
# Iter: 5663, running avg mse: 0.0938 lowest val mse: 0.0847 at k 3
# Iter: 5664, running avg mse: 0.0904 lowest val mse: 0.0841 at k 3
# Iter: 5665, running avg mse: 0.0890 lowest val mse: 0.0798 at k 3
# Iter: 5666, running avg mse: 0.0886 lowest val mse: 0.0786 at k 3
# Iter: 5667, running avg mse: 0.0940 lowest val mse: 0.0817 at k 3
# Iter: 5668, running avg mse: 0.1044 lowest val mse: 0.0860 at k 3
# Iter: 5669, running avg mse: 0.1102 lowest val mse: 0.0923 at k 3
# Iter: 5670, running avg mse: 0.1031 lowest val mse: 0.0801 at k 3
# Iter: 5671, running avg mse: 0.1017 lowest val mse: 0.0875 at k 3
# Iter: 5672, running avg mse: 0.0946 lowest val mse: 0.0990 at k 3
# Iter: 5673, running avg mse: 0.0998 lowest val mse: 0.0916 at k 3
# Iter: 5674, running avg mse: 0.1004 lowest val mse: 0.1173 at k 3
# Iter: 5675, running avg mse: 0.1109 lowest val mse: 0.1145 at k 2
# Iter: 5676, running avg mse: 0.0969 lowest val mse: 0.1059 at k 3
# Iter: 5677, running avg mse: 0.1067 lowest val mse: 0.0964 at k 3
# Iter: 5678, running avg mse: 0.0970 lowest val mse: 0.0995 at k 3
# Iter: 5679, running avg mse: 0.1092 lowest val mse: 0.1012 at k 3
# Iter: 5680, running avg mse: 0.1027 lowest val mse: 0.0954 at k 4
# Iter: 5681, running avg mse: 0.1036 lowest val mse: 0.0884 at k 4
# Iter: 5682, running avg mse: 0.0962 lowest val mse: 0.0854 at k 3
# Iter: 5683, running avg mse: 0.0950 lowest val mse: 0.0838 at k 3
# Iter: 5684, running avg mse: 0.1046 lowest val mse: 0.0810 at k 3
# Iter: 5685, running avg mse: 0.1091 lowest val mse: 0.0903 at k 3
# Iter: 5686, running avg mse: 0.1064 lowest val mse: 0.1048 at k 3
# Iter: 5687, running avg mse: 0.0957 lowest val mse: 0.0794 at k 3
# Iter: 5688, running avg mse: 0.0920 lowest val mse: 0.0844 at k 3
# Iter: 5689, running avg mse: 0.0893 lowest val mse: 0.0807 at k 3
# Iter: 5690, running avg mse: 0.0852 lowest val mse: 0.0793 at k 3
# Iter: 5691, running avg mse: 0.0831 lowest val mse: 0.0839 at k 3
# Iter: 5692, running avg mse: 0.0931 lowest val mse: 0.0822 at k 3
# Iter: 5693, running avg mse: 0.0842 lowest val mse: 0.0747 at k 3
# Iter: 5694, running avg mse: 0.0869 lowest val mse: 0.0851 at k 3
# Iter: 5695, running avg mse: 0.0835 lowest val mse: 0.0886 at k 3
# Iter: 5696, running avg mse: 0.0830 lowest val mse: 0.0871 at k 3
# Iter: 5697, running avg mse: 0.0866 lowest val mse: 0.0933 at k 3
# Iter: 5698, running avg mse: 0.0918 lowest val mse: 0.0846 at k 2
# Iter: 5699, running avg mse: 0.0874 lowest val mse: 0.0839 at k 3
# Iter: 5700, running avg mse: 0.0841 lowest val mse: 0.0976 at k 3
# Iter: 5701, running avg mse: 0.0938 lowest val mse: 0.0997 at k 3
# Iter: 5702, running avg mse: 0.0957 lowest val mse: 0.1030 at k 3
# Iter: 5703, running avg mse: 0.1058 lowest val mse: 0.1100 at k 3
# Iter: 5704, running avg mse: 0.1059 lowest val mse: 0.1153 at k 3
# Iter: 5705, running avg mse: 0.1127 lowest val mse: 0.0961 at k 3
# Iter: 5706, running avg mse: 0.0954 lowest val mse: 0.0895 at k 3
# Iter: 5707, running avg mse: 0.0982 lowest val mse: 0.0854 at k 3
# Iter: 5708, running avg mse: 0.0900 lowest val mse: 0.0838 at k 3
# Iter: 5709, running avg mse: 0.0914 lowest val mse: 0.0906 at k 3
# Iter: 5710, running avg mse: 0.0969 lowest val mse: 0.0967 at k 2
# Iter: 5711, running avg mse: 0.0953 lowest val mse: 0.0814 at k 3
# Iter: 5712, running avg mse: 0.0928 lowest val mse: 0.0847 at k 3
# Iter: 5713, running avg mse: 0.0971 lowest val mse: 0.1007 at k 2
# Iter: 5714, running avg mse: 0.1020 lowest val mse: 0.1008 at k 3
# Iter: 5715, running avg mse: 0.0869 lowest val mse: 0.0881 at k 3
# Iter: 5716, running avg mse: 0.0902 lowest val mse: 0.0969 at k 3
# Iter: 5717, running avg mse: 0.0927 lowest val mse: 0.0899 at k 2
# Iter: 5718, running avg mse: 0.0916 lowest val mse: 0.0864 at k 3
# Iter: 5719, running avg mse: 0.0987 lowest val mse: 0.0810 at k 3
# Iter: 5720, running avg mse: 0.0914 lowest val mse: 0.0846 at k 3
# Iter: 5721, running avg mse: 0.0945 lowest val mse: 0.0917 at k 3
# Iter: 5722, running avg mse: 0.0958 lowest val mse: 0.0910 at k 2
# Iter: 5723, running avg mse: 0.0979 lowest val mse: 0.0810 at k 3
# Iter: 5724, running avg mse: 0.0928 lowest val mse: 0.0774 at k 3
# Iter: 5725, running avg mse: 0.0919 lowest val mse: 0.0774 at k 3
# Iter: 5726, running avg mse: 0.0902 lowest val mse: 0.0763 at k 3
# Iter: 5727, running avg mse: 0.0928 lowest val mse: 0.0781 at k 2
# ...
# Iter: 6954, running avg mse: 0.2149 lowest val mse: 0.1620 at k 3
# Iter: 6955, running avg mse: 0.1692 lowest val mse: 0.1554 at k 3
# Iter: 6956, running avg mse: 0.1824 lowest val mse: 0.1604 at k 4
# Iter: 6957, running avg mse: 0.1740 lowest val mse: 0.1778 at k 4
# Iter: 6958, running avg mse: 0.1646 lowest val mse: 0.1721 at k 4
# Iter: 6959, running avg mse: 0.2188 lowest val mse: 0.1941 at k 3
# Iter: 6960, running avg mse: 0.1850 lowest val mse: 0.1417 at k 4
# Iter: 6961, running avg mse: 0.1726 lowest val mse: 0.1920 at k 2
# Iter: 6962, running avg mse: 0.1603 lowest val mse: 0.1298 at k 3
# Iter: 6963, running avg mse: 0.1485 lowest val mse: 0.1390 at k 3
# Iter: 6964, running avg mse: 0.1513 lowest val mse: 0.1272 at k 3
# Iter: 6965, running avg mse: 0.1396 lowest val mse: 0.1472 at k 4
# Iter: 6966, running avg mse: 0.1598 lowest val mse: 0.1220 at k 3
# Iter: 6967, running avg mse: 0.1423 lowest val mse: 0.1281 at k 3
# Iter: 6968, running avg mse: 0.1531 lowest val mse: 0.1355 at k 3
# Iter: 6969, running avg mse: 0.1477 lowest val mse: 0.1507 at k 3
# Iter: 6970, running avg mse: 0.1460 lowest val mse: 0.1258 at k 4
# Iter: 6971, running avg mse: 0.1294 lowest val mse: 0.1258 at k 3
# Iter: 6972, running avg mse: 0.1422 lowest val mse: 0.1157 at k 3
# Iter: 6973, running avg mse: 0.1268 lowest val mse: 0.1295 at k 3
# Iter: 6974, running avg mse: 0.1430 lowest val mse: 0.1319 at k 3
# Iter: 6975, running avg mse: 0.1375 lowest val mse: 0.1275 at k 3
# Iter: 6976, running avg mse: 0.1345 lowest val mse: 0.1171 at k 3
# Iter: 6977, running avg mse: 0.1342 lowest val mse: 0.1406 at k 4
# Iter: 6978, running avg mse: 0.1453 lowest val mse: 0.1361 at k 3
# Iter: 6979, running avg mse: 0.1663 lowest val mse: 0.1371 at k 3
# Iter: 6980, running avg mse: 0.1637 lowest val mse: 0.1466 at k 3
# Iter: 6981, running avg mse: 0.1547 lowest val mse: 0.1279 at k 2
# Iter: 6982, running avg mse: 0.1484 lowest val mse: 0.1462 at k 4
# Iter: 6983, running avg mse: 0.1549 lowest val mse: 0.1849 at k 3
# Iter: 6984, running avg mse: 0.1574 lowest val mse: 0.1684 at k 4
# Iter: 6985, running avg mse: 0.2115 lowest val mse: 0.1764 at k 4
# Iter: 6986, running avg mse: 0.1830 lowest val mse: 0.1625 at k 4
# Iter: 6987, running avg mse: 0.1616 lowest val mse: 0.1697 at k 4
# Iter: 6988, running avg mse: 0.1776 lowest val mse: 0.1624 at k 4
# Iter: 6989, running avg mse: 0.1650 lowest val mse: 0.1439 at k 3
# Iter: 6990, running avg mse: 0.1738 lowest val mse: 0.1761 at k 4
# Iter: 6991, running avg mse: 0.1765 lowest val mse: 0.1697 at k 3
# Iter: 6992, running avg mse: 0.1994 lowest val mse: 0.1513 at k 3
# Iter: 6993, running avg mse: 0.1524 lowest val mse: 0.1716 at k 3
# Iter: 6994, running avg mse: 0.1745 lowest val mse: 0.1542 at k 4
# Iter: 6995, running avg mse: 0.1608 lowest val mse: 0.1651 at k 4
# Iter: 6996, running avg mse: 0.1848 lowest val mse: 0.2060 at k 4
# Iter: 6997, running avg mse: 0.1825 lowest val mse: 0.1583 at k 3
# Iter: 6998, running avg mse: 0.1661 lowest val mse: 0.1820 at k 4
# Iter: 6999, running avg mse: 0.1930 lowest val mse: 0.1534 at k 2
# Iter: 7000, running avg mse: 0.1621 lowest val mse: 0.1443 at k 3
# Iter: 7001, running avg mse: 0.1726 lowest val mse: 0.1647 at k 4
# Iter: 7002, running avg mse: 0.1525 lowest val mse: 0.1323 at k 3
# Iter: 7003, running avg mse: 0.1393 lowest val mse: 0.1187 at k 2
# Iter: 7004, running avg mse: 0.1320 lowest val mse: 0.1254 at k 4
# Iter: 7005, running avg mse: 0.1314 lowest val mse: 0.1146 at k 3
# Iter: 7006, running avg mse: 0.1339 lowest val mse: 0.1095 at k 3
# Iter: 7007, running avg mse: 0.1170 lowest val mse: 0.1266 at k 3
# Iter: 7008, running avg mse: 0.1207 lowest val mse: 0.1130 at k 3
# Iter: 7009, running avg mse: 0.1274 lowest val mse: 0.1321 at k 3
# Iter: 7010, running avg mse: 0.1281 lowest val mse: 0.1275 at k 2
# Iter: 7011, running avg mse: 0.1228 lowest val mse: 0.1147 at k 4
# Iter: 7012, running avg mse: 0.1204 lowest val mse: 0.1345 at k 3
# Iter: 7013, running avg mse: 0.1274 lowest val mse: 0.1176 at k 3
# Iter: 7014, running avg mse: 0.1302 lowest val mse: 0.1166 at k 4
# Iter: 7015, running avg mse: 0.1270 lowest val mse: 0.1382 at k 3
# Iter: 7016, running avg mse: 0.1527 lowest val mse: 0.1328 at k 3
# Iter: 7017, running avg mse: 0.1474 lowest val mse: 0.1109 at k 3
# Iter: 7018, running avg mse: 0.1218 lowest val mse: 0.1508 at k 4
# Iter: 7019, running avg mse: 0.1397 lowest val mse: 0.1256 at k 3
# Iter: 7020, running avg mse: 0.1340 lowest val mse: 0.1187 at k 3
# Iter: 7021, running avg mse: 0.1442 lowest val mse: 0.1279 at k 4
# Iter: 7022, running avg mse: 0.1460 lowest val mse: 0.1028 at k 3
# Iter: 7023, running avg mse: 0.1335 lowest val mse: 0.1153 at k 3
# Iter: 7024, running avg mse: 0.1253 lowest val mse: 0.1106 at k 3
# Iter: 7025, running avg mse: 0.1362 lowest val mse: 0.1213 at k 3
# Iter: 7026, running avg mse: 0.1438 lowest val mse: 0.1222 at k 4
# Iter: 7027, running avg mse: 0.1176 lowest val mse: 0.1106 at k 3
# Iter: 7028, running avg mse: 0.1411 lowest val mse: 0.1191 at k 3
# Iter: 7029, running avg mse: 0.1138 lowest val mse: 0.1112 at k 2
# Iter: 7030, running avg mse: 0.1158 lowest val mse: 0.1094 at k 4
# Iter: 7031, running avg mse: 0.1144 lowest val mse: 0.1141 at k 4
# Iter: 7032, running avg mse: 0.1227 lowest val mse: 0.1048 at k 3
# Iter: 7033, running avg mse: 0.1091 lowest val mse: 0.1043 at k 3
# Iter: 7034, running avg mse: 0.1154 lowest val mse: 0.1009 at k 4
# Iter: 7035, running avg mse: 0.1154 lowest val mse: 0.1051 at k 4
# Iter: 7036, running avg mse: 0.1209 lowest val mse: 0.1235 at k 3
# Iter: 7037, running avg mse: 0.1164 lowest val mse: 0.1021 at k 3
# Iter: 7038, running avg mse: 0.1239 lowest val mse: 0.0912 at k 4
# Iter: 7039, running avg mse: 0.1156 lowest val mse: 0.1032 at k 3
# Iter: 7040, running avg mse: 0.1124 lowest val mse: 0.1148 at k 2
# Iter: 7041, running avg mse: 0.1282 lowest val mse: 0.1028 at k 3
# Iter: 7042, running avg mse: 0.1078 lowest val mse: 0.1011 at k 3
# Iter: 7043, running avg mse: 0.1134 lowest val mse: 0.0955 at k 3
# Iter: 7044, running avg mse: 0.1149 lowest val mse: 0.1064 at k 4
# Iter: 7045, running avg mse: 0.1093 lowest val mse: 0.1025 at k 3
# Iter: 7046, running avg mse: 0.1149 lowest val mse: 0.1225 at k 3
# Iter: 7047, running avg mse: 0.1115 lowest val mse: 0.1059 at k 3
# Iter: 7048, running avg mse: 0.1153 lowest val mse: 0.1041 at k 3
# Iter: 7049, running avg mse: 0.1089 lowest val mse: 0.0987 at k 2
# Iter: 7050, running avg mse: 0.1110 lowest val mse: 0.0857 at k 3
# Iter: 7051, running avg mse: 0.1017 lowest val mse: 0.0909 at k 3
# Iter: 7052, running avg mse: 0.1072 lowest val mse: 0.0928 at k 4
# Iter: 7053, running avg mse: 0.0966 lowest val mse: 0.0928 at k 4
# Iter: 7054, running avg mse: 0.1049 lowest val mse: 0.0990 at k 4
# Iter: 7055, running avg mse: 0.1051 lowest val mse: 0.0970 at k 3
# Iter: 7056, running avg mse: 0.1004 lowest val mse: 0.0939 at k 3
# Iter: 7057, running avg mse: 0.1035 lowest val mse: 0.0908 at k 3
# Iter: 7058, running avg mse: 0.0978 lowest val mse: 0.0906 at k 3
# Iter: 7059, running avg mse: 0.0966 lowest val mse: 0.0931 at k 3
# Iter: 7060, running avg mse: 0.1019 lowest val mse: 0.0927 at k 3
# Iter: 7061, running avg mse: 0.0898 lowest val mse: 0.0881 at k 3
# Iter: 7062, running avg mse: 0.0951 lowest val mse: 0.0994 at k 3
# Iter: 7063, running avg mse: 0.0929 lowest val mse: 0.0866 at k 3
# Iter: 7064, running avg mse: 0.0924 lowest val mse: 0.0934 at k 3
# Iter: 7065, running avg mse: 0.0975 lowest val mse: 0.0898 at k 2
# Iter: 7066, running avg mse: 0.0995 lowest val mse: 0.0855 at k 3
# Iter: 7067, running avg mse: 0.0938 lowest val mse: 0.0837 at k 3
# Iter: 7068, running avg mse: 0.0951 lowest val mse: 0.0886 at k 3
# Iter: 7069, running avg mse: 0.0911 lowest val mse: 0.0954 at k 3
# Iter: 7070, running avg mse: 0.0979 lowest val mse: 0.1103 at k 3
# Iter: 7071, running avg mse: 0.1085 lowest val mse: 0.1056 at k 4
# Iter: 7072, running avg mse: 0.0986 lowest val mse: 0.0967 at k 3
# Iter: 7073, running avg mse: 0.1005 lowest val mse: 0.0882 at k 3
# Iter: 7074, running avg mse: 0.0933 lowest val mse: 0.1057 at k 2
# Iter: 7075, running avg mse: 0.0886 lowest val mse: 0.0931 at k 3
# Iter: 7076, running avg mse: 0.0917 lowest val mse: 0.0900 at k 3
# Iter: 7077, running avg mse: 0.0921 lowest val mse: 0.0925 at k 3
# Iter: 7078, running avg mse: 0.1019 lowest val mse: 0.0904 at k 3
# Iter: 7079, running avg mse: 0.0970 lowest val mse: 0.0848 at k 3
# Iter: 7080, running avg mse: 0.0914 lowest val mse: 0.0892 at k 4
# Iter: 7081, running avg mse: 0.0960 lowest val mse: 0.0961 at k 3
# Iter: 7082, running avg mse: 0.0938 lowest val mse: 0.0888 at k 3
# Iter: 7083, running avg mse: 0.0948 lowest val mse: 0.0899 at k 3
# Iter: 7084, running avg mse: 0.0948 lowest val mse: 0.0826 at k 2
# Iter: 7085, running avg mse: 0.1006 lowest val mse: 0.0826 at k 3
# Iter: 7086, running avg mse: 0.0919 lowest val mse: 0.0813 at k 3
# Iter: 7087, running avg mse: 0.0933 lowest val mse: 0.0864 at k 3
# Iter: 7088, running avg mse: 0.0918 lowest val mse: 0.0910 at k 2
# Iter: 7089, running avg mse: 0.0949 lowest val mse: 0.0897 at k 3
# Iter: 7090, running avg mse: 0.0922 lowest val mse: 0.0902 at k 4
# Iter: 7091, running avg mse: 0.1025 lowest val mse: 0.0890 at k 3
# Iter: 7092, running avg mse: 0.1011 lowest val mse: 0.0961 at k 3
# Iter: 7093, running avg mse: 0.1041 lowest val mse: 0.1052 at k 3
# Iter: 7094, running avg mse: 0.1111 lowest val mse: 0.0893 at k 3
# Iter: 7095, running avg mse: 0.1135 lowest val mse: 0.0991 at k 3
# Iter: 7096, running avg mse: 0.1071 lowest val mse: 0.0911 at k 4
# Iter: 7097, running avg mse: 0.0975 lowest val mse: 0.0831 at k 3
# Iter: 7098, running avg mse: 0.0942 lowest val mse: 0.0815 at k 3
# Iter: 7099, running avg mse: 0.0890 lowest val mse: 0.0843 at k 3
# Iter: 7100, running avg mse: 0.0900 lowest val mse: 0.0858 at k 3
# Iter: 7101, running avg mse: 0.0969 lowest val mse: 0.0883 at k 3
# Iter: 7102, running avg mse: 0.0961 lowest val mse: 0.0880 at k 2
# Iter: 7103, running avg mse: 0.0958 lowest val mse: 0.0841 at k 3
# Iter: 7104, running avg mse: 0.0944 lowest val mse: 0.0849 at k 3
# Iter: 7105, running avg mse: 0.0970 lowest val mse: 0.0893 at k 3
# Iter: 7106, running avg mse: 0.0943 lowest val mse: 0.0835 at k 3
# Iter: 7107, running avg mse: 0.0857 lowest val mse: 0.0893 at k 3
# Iter: 7108, running avg mse: 0.0881 lowest val mse: 0.0886 at k 3
# Iter: 7109, running avg mse: 0.0947 lowest val mse: 0.1042 at k 3
# Iter: 7110, running avg mse: 0.1047 lowest val mse: 0.1014 at k 3
# Iter: 7111, running avg mse: 0.0993 lowest val mse: 0.0964 at k 4
# Iter: 7112, running avg mse: 0.1027 lowest val mse: 0.1021 at k 3
# Iter: 7113, running avg mse: 0.0981 lowest val mse: 0.0883 at k 2
# Iter: 7114, running avg mse: 0.0964 lowest val mse: 0.0905 at k 3
# Iter: 7115, running avg mse: 0.0942 lowest val mse: 0.0847 at k 3
# Iter: 7116, running avg mse: 0.1001 lowest val mse: 0.0898 at k 3
# Iter: 7117, running avg mse: 0.0926 lowest val mse: 0.0917 at k 3
# Iter: 7118, running avg mse: 0.0929 lowest val mse: 0.0855 at k 4
# Iter: 7119, running avg mse: 0.0945 lowest val mse: 0.0867 at k 3
# Iter: 7120, running avg mse: 0.0892 lowest val mse: 0.0743 at k 3
# Iter: 7121, running avg mse: 0.0931 lowest val mse: 0.0861 at k 3
# Iter: 7122, running avg mse: 0.0915 lowest val mse: 0.0793 at k 2
# Iter: 7123, running avg mse: 0.0889 lowest val mse: 0.0858 at k 3
# Iter: 7124, running avg mse: 0.0905 lowest val mse: 0.0847 at k 3
# Iter: 7125, running avg mse: 0.0878 lowest val mse: 0.0813 at k 3
# Iter: 7126, running avg mse: 0.0907 lowest val mse: 0.0808 at k 2
# Iter: 7127, running avg mse: 0.0873 lowest val mse: 0.0832 at k 3
# Iter: 7128, running avg mse: 0.0881 lowest val mse: 0.0855 at k 3
# Iter: 7129, running avg mse: 0.0913 lowest val mse: 0.0782 at k 3
# Iter: 7130, running avg mse: 0.0934 lowest val mse: 0.0818 at k 2
# Iter: 7131, running avg mse: 0.0867 lowest val mse: 0.0763 at k 3
# Iter: 7132, running avg mse: 0.0938 lowest val mse: 0.0835 at k 2
# Iter: 7133, running avg mse: 0.0899 lowest val mse: 0.0879 at k 4
# Iter: 7134, running avg mse: 0.0939 lowest val mse: 0.0845 at k 3
# Iter: 7135, running avg mse: 0.0903 lowest val mse: 0.0822 at k 3
# Iter: 7136, running avg mse: 0.0911 lowest val mse: 0.0789 at k 3
# Iter: 7137, running avg mse: 0.0878 lowest val mse: 0.0816 at k 3
# Iter: 7138, running avg mse: 0.0908 lowest val mse: 0.0833 at k 3
# Iter: 7139, running avg mse: 0.0912 lowest val mse: 0.0844 at k 3
# Iter: 7140, running avg mse: 0.0910 lowest val mse: 0.0830 at k 3
# Iter: 7141, running avg mse: 0.0918 lowest val mse: 0.0821 at k 3
# Iter: 7142, running avg mse: 0.0956 lowest val mse: 0.0910 at k 3
# Iter: 7143, running avg mse: 0.0910 lowest val mse: 0.0874 at k 3
# Iter: 7144, running avg mse: 0.0913 lowest val mse: 0.0820 at k 3
# Iter: 7145, running avg mse: 0.0930 lowest val mse: 0.0799 at k 3
# Iter: 7146, running avg mse: 0.1019 lowest val mse: 0.0936 at k 2
# Iter: 7147, running avg mse: 0.1041 lowest val mse: 0.0853 at k 3
# Iter: 7148, running avg mse: 0.0950 lowest val mse: 0.0872 at k 3
# Iter: 7149, running avg mse: 0.0940 lowest val mse: 0.0836 at k 4
# Iter: 7150, running avg mse: 0.0977 lowest val mse: 0.0979 at k 4
# Iter: 7151, running avg mse: 0.0939 lowest val mse: 0.0904 at k 4
# Iter: 7152, running avg mse: 0.0918 lowest val mse: 0.0813 at k 2
# Iter: 7153, running avg mse: 0.0991 lowest val mse: 0.0951 at k 4
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 16
#      13 z0 = epsilon * torch.exp(.5 * qz0_logvar) + qz0_mean
#      15 # forward in time and solve ode for reconstructions
# ---> 16 pred_z = odeint(func, z0, samp_ts).permute(1, 0, 2)
#      17 pred_x = dec(pred_z)
#      19 # compute loss
#
# File ~\Documents\NeuralODE_HumanGait\torchdiffeq\_impl\adjoint.py:206, in odeint_adjoint(func, y0, t, rtol, atol, method, options, event_fn, adjoint_rtol, adjoint_atol, adjoint_method, adjoint_options, adjoint_params)
#     203 state_norm = options["norm"]
#     204 handle_adjoint_norm_(adjoint_options, shapes, state_norm)
# --> 206 ans = OdeintAdjointMethod.apply(shapes, func, y0, t, rtol, atol, method, options, event_fn, adjoint_rtol, adjoint_atol,
#     207                                 adjoint_method, adjoint_options, t.requires_grad, *adjoint_params)
#     209 if event_fn is None:
#     210     solution = ans
#
# File ~\Documents\NeuralODE_HumanGait\torchdiffeq\_impl\adjoint.py:24, in OdeintAdjointMethod.forward(ctx, shapes, func, y0, t, rtol, atol, method, options, event_fn, adjoint_rtol, adjoint_atol, adjoint_method, adjoint_options, t_requires_grad, *adjoint_params)
#      21 ctx.event_mode = event_fn is not None
#      23 with torch.no_grad():
# ---> 24     ans = odeint(func, y0, t, rtol=rtol, atol=atol, method=method, options=options, event_fn=event_fn)
#      26     if event_fn is None:
#      27         y = ans
#
# File ~\Documents\NeuralODE_HumanGait\torchdiffeq\_impl\odeint.py:77, in odeint(func, y0, t, rtol, atol, method, options, event_fn)
#      74 solver = SOLVERS[method](func=func, y0=y0, rtol=rtol, atol=atol, **options)
#      76 if event_fn is None:
# ---> 77     solution = solver.integrate(t)
#      78 else:
#      79     event_t, solution = solver.integrate_until_event(t[0], event_fn)
#
# File ~\Documents\NeuralODE_HumanGait\torchdiffeq\_impl\solvers.py:34, in AdaptiveStepsizeODESolver.integrate(self, t)
#      32 self._before_integrate(t)
#      33 for i in range(1, len(t)):
# ---> 34     solution[i] = self._advance(t[i])
#      35 return solution
#
# File ~\Documents\NeuralODE_HumanGait\torchdiffeq\_impl\rk_common.py:206, in RKAdaptiveStepsizeODESolver._advance(self, next_t)
#     204     self.rk_state = self._adaptive_step(self.rk_state)
#     205     n_steps += 1
# --> 206 return _interp_evaluate(self.rk_state.interp_coeff, self.rk_state.t0, self.rk_state.t1, next_t)
#
# File ~\Documents\NeuralODE_HumanGait\torchdiffeq\_impl\interp.py:46, in _interp_evaluate(coefficients, t0, t1, t)
#      44 for coefficient in coefficients[2:]:
#      45     x_power = x_power * x
# ---> 46     total = total + x_power * coefficient
#      48 return total
#
# KeyboardInterrupt:

# %%
save_model(tau, k, latent_dim, itr)

# %%
checkpoint = torch.load('model/ODE_TakenEmbedding_RLONG_rnn2_lstm256_tau18k5_LSTM_lr0.008_latent12_LSTMautoencoder_Dataloader_timestep500_epoch1410.pth')
rec.load_state_dict(checkpoint['encoder_state_dict'])
func.load_state_dict(checkpoint['odefunc_state_dict'])
dec.load_state_dict(checkpoint['decoder_state_dict'])
# Out:
# <All keys matched successfully>

# %%
        save_model(tau, k, latent_dim, itr)
        gen_index = 3
        times_index = 0
        tot_index = 15
        deriv_index = deriv_index.numpy()
        
        orig_trajs = orig_trajs_TE[:, 0:0+150*6, :]

        pred_x, pred_z = data_for_plot_graph(tot_index)
        pred_x = pred_x.reshape(72, 300*tot_index, 6*(k+1))
        pred_z = pred_z.reshape(72, 300*tot_index, latent_dim)
        pred_x_forgraph = pred_x.detach().cpu().numpy()
        pred_z_forgraph = pred_z.detach().cpu().numpy()

        path = "Results_pic/tau{}k{}/longtimeseries/latent{}/RLONG_data_loader_rnn2layer_lstm{}_lr0.008/epoch{}".format(tau, k, latent_dim, rnn_nhidden, itr)

        if not os.path.exists(path):
           os.makedirs(path)

        
        plotgraph_index = [0, 1, 2, 3, 4, 5, 18, 19, 20, 21, 22, 23, 48, 49, 50, 51, 52, 53,  60, 61, 62, 63, 64, 65]
        
        tot_index = 3
        
        for i in range(72):
            plot_graph(3, times_index, tot_index, i, deriv_index, pred_x_forgraph, orig_trajs, itr, path)
            
        tot_index = 15
        
        for i in range(72):
            plot_graph(3, times_index, tot_index, i, deriv_index, pred_x_forgraph, orig_trajs, itr, path)

# %%
        gen_index = 50
        times_index = 0
        deriv_index = deriv_index.numpy()
        
        orig_trajs = orig_trajs_TE[:, 0:0+50*gen_index, :]

        pred_x, pred_z = data_for_plot_graph(gen_index)
        pred_x = pred_x.reshape(203, 50*gen_index, 31*(k+1)+2)
        pred_z = pred_z.reshape(203, 50*gen_index, latent_dim)
        pred_x_forgraph = pred_x.detach().cpu().numpy()
        pred_z_forgraph = pred_z.detach().cpu().numpy()

        path = "Results_pic/tau{}k{}/longtimeseries/latent{}/data_loader_rnn2layer_lstm{}_lr0.008/epoch{}".format(tau, k, latent_dim, rnn_nhidden, itr)

        if not os.path.exists(path):
           os.makedirs(path)

        gen_index = 15
        plotgraph_index = [0, 4, 20, 24, 28, 42, 43, 44, 45, 46, 47, 65]
        
        for i in range(len(plotgraph_index)):
            plot_graph(gen_index, times_index, plotgraph_index[i], deriv_index, pred_x_forgraph, orig_trajs, itr, path)
        
        gen_index = 30
        
        for i in range(len(plotgraph_index)):
            plot_graph(gen_index, times_index, plotgraph_index[i], deriv_index, pred_x_forgraph, orig_trajs, itr, path)
            
        gen_index = 50
        
        for i in range(len(plotgraph_index)):
            plot_graph(gen_index, times_index, plotgraph_index[i], deriv_index, pred_x_forgraph, orig_trajs, itr, path)

# %%
deriv_index
# Out:
# 0

# %%
V
# Out:
# [array(0.35570502, dtype=float32),
#  array(0.34477258, dtype=float32),
#  array(0.33471537, dtype=float32),
#  array(0.3282059, dtype=float32)]

# %%
train_loss = np.array(train_losses)

plt.plot(train_loss, 'r')
plt.savefig('C:/Users/shiny/Documents/NeuralODE_RatTreadMill/Results_pic/TrainingLossGraph/tau6k3/trainloss_0.005_nonoise_latent8_lstm256.png')
np.save('C:/Users/shiny/Documents/NeuralODE_RatTreadMill/Results_pic/TrainingLossGraph/tau6k3/trainloss_0.005_nonoise_latent8_lstm256.npy', train_loss)

# %%
folder = 'runs/model_'

def save_model():
    folder = 'runs/model'
    folder = os.path.join(folder, 'ckpt')

    ckpt_path = os.path.join(folder, f'ODE_normalized_4_128_2tanh.pth')

    save_dict = {
        'model_args': get_args(),
        'optimizer_state_dict': optimizer.state_dict(),
        'data': data_get_dict(),
        'train_loss': get_losses()
    }
    
    save_dict.update(get_state_dicts())
    
    torch.save(save_dict, 'C:/Users/shiny/Documents/NeuralODE_RatTreadMill/model/All_rodent_ODE_TakenEmbedding_tau6k3_LSTM_lr0.008_latent8_LSTMautoencoder_epoch500.pth')

save_model()

# %%
checkpoint = torch.load('model/All_rodent_ODE_TakenEmbedding_tau6k3_LSTM_lr0.008_latent8_LSTMautoencoder_epoch380.pth')
rec.load_state_dict(checkpoint['encoder_state_dict'])
func.load_state_dict(checkpoint['odefunc_state_dict'])
dec.load_state_dict(checkpoint['decoder_state_dict'])
# Out:
# <All keys matched successfully>

# %% [markdown]
# ## Long time series generation

# %%
gen_index = 20
times_index = 0
deriv_index = 0
itr= 380
orig_trajs_TE = np.load('orig_trajs_TE_tau6k3.npy')
orig_trajs_TE = orig_trajs_TE.reshape(203, 200*34, 31*(k+1)+2)
samp_trajs_TE_test = orig_trajs_TE[:, :50, :]

samp_trajs_TE_test = torch.from_numpy(samp_trajs_TE_test).float().to(device).reshape(203, 50, 31*(k+1)+2)
orig_trajs = orig_trajs_TE[:, 0:0+50*gen_index, :]

pred_x = data_for_plot_graph(gen_index)

path = "Results_pic/tau6k3/longtimeseries/epoch{}".format(itr)

if not os.path.exists(path):
   os.makedirs(path)

plot_graph(gen_index, times_index, 0, deriv_index, pred_x, orig_trajs, itr, path)
plot_graph(gen_index, times_index, 4, deriv_index, pred_x, orig_trajs, itr, path)
plot_graph(gen_index, times_index, 20, deriv_index, pred_x, orig_trajs, itr, path)

# %%
with torch.no_grad():
    # sample from trajectorys' approx. posterior

    ts_pos = np.linspace(0, 0.25*gen_index, num=50*gen_index)
    ts_pos = torch.from_numpy(ts_pos).float().to(device)
    
    h = torch.zeros(1, samp_trajs_TE.shape[0], rnn_nhidden).to(device)
    c = torch.zeros(1, samp_trajs_TE.shape[0], rnn_nhidden).to(device)
    
    hn = h[0, :, :]
    cn = c[0, :, :]
    
    for t in reversed(range(samp_trajs_TE.size(1))):
        obs = samp_trajs_TE[:, t, :]
        out, hn, cn = rec.forward(obs, hn, cn)
    qz0_mean, qz0_logvar = out[:, :latent_dim], out[:, latent_dim:]
    epsilon = torch.randn(qz0_mean.size()).to(device)
    z0 = epsilon * torch.exp(.5 * qz0_logvar) + qz0_mean

    # forward in time and solve ode for reconstructions
    pred_z = odeint(func, z0, ts_pos).permute(1, 0, 2) #change time and batch with permute
    pred_x = dec(pred_z)

# %%
with torch.no_grad():
    samp_ts_forgraph = samp_ts.detach().cpu().numpy()
    pred_x = pred_x.reshape(203, 50*gen_index, 28*(k+1)+2)
    pred_x_forgraph = pred_x.detach().cpu().numpy()
    orig_trajs_forgraph = orig_trajs
    ts_pos_forgraph = ts_pos.detach().cpu().numpy()
    ts_pos_combined = np.linspace(0, 0.25*gen_index, num=50*gen_index) 
    
    times_index = 0
    dataset_value = 0
    deriv_index = 0
    fig, axes = plt.subplots(nrows=6, ncols=5, figsize=(15, 9))
    axes = axes.flatten()
    for i, ax in enumerate(axes):
        ax.scatter(ts_pos_combined[times_index:50*gen_index], orig_trajs_forgraph[dataset_value,0:50*gen_index, i], label='sampled data', s = 5)
        ax.plot(ts_pos_combined[times_index:+50*gen_index], pred_x_forgraph[dataset_value, times_index:+50*gen_index, i*(k+1)+deriv_index], 'r',
                 label='learned trajectory (t>0)')

    plt.legend()
    plt.savefig('./Results_pic/tau6k3/longtimeseries/lstm_Tied_latent8_gen10_deriv0_50.png', dpi=500)
    #plt.savefig('./minibatchfps200_take300_predict900_positionalvalue3.png', dpi=500)
    print('Saved visualization figure at {}'.format('./test.png'))
# Out:
# Saved visualization figure at ./test.png

# %%
with torch.no_grad():
    samp_ts_forgraph = samp_ts.detach().cpu().numpy()
    pred_x = pred_x.reshape(203, 50*gen_index, 28*(k+1)+2)
    pred_x_forgraph = pred_x.detach().cpu().numpy()
    orig_trajs_forgraph = orig_trajs
    ts_pos_forgraph = ts_pos.detach().cpu().numpy()
    ts_pos_combined = np.linspace(0, 0.25*gen_index, num=50*gen_index) 
    
    times_index = 0
    dataset_value = 4
    deriv_index = 0
    fig, axes = plt.subplots(nrows=6, ncols=5, figsize=(15, 9))
    axes = axes.flatten()
    for i, ax in enumerate(axes):
        ax.scatter(ts_pos_combined[times_index:50*gen_index], orig_trajs_forgraph[dataset_value,0:50*gen_index, i], label='sampled data', s = 5)
        ax.plot(ts_pos_combined[times_index:+50*gen_index], pred_x_forgraph[dataset_value, times_index:+50*gen_index, i*(k+1)+deriv_index], 'r',
                 label='learned trajectory (t>0)')

    plt.legend()
    plt.savefig('./Results_pic/tau6k3/longtimeseries/lstm_split_latent8_gen10_deriv0_50.png', dpi=500)
    #plt.savefig('./minibatchfps200_take300_predict900_positionalvalue3.png', dpi=500)
    print('Saved visualization figure at {}'.format('./test.png'))
# Out:
# Saved visualization figure at ./test.png

# %%
with torch.no_grad():
    samp_ts_forgraph = samp_ts.detach().cpu().numpy()
    pred_x = pred_x.reshape(203, 50*gen_index, 28*(k+1)+2)
    pred_x_forgraph = pred_x.detach().cpu().numpy()
    orig_trajs_forgraph = orig_trajs
    ts_pos_forgraph = ts_pos.detach().cpu().numpy()
    ts_pos_combined = np.linspace(0, 0.25*gen_index, num=50*gen_index) 
    
    times_index = 0
    dataset_value = 20
    deriv_index = 0
    fig, axes = plt.subplots(nrows=6, ncols=5, figsize=(15, 9))
    axes = axes.flatten()
    for i, ax in enumerate(axes):
        ax.scatter(ts_pos_combined[times_index:50*gen_index], orig_trajs_forgraph[dataset_value,0:50*gen_index, i], label='sampled data', s = 5)
        ax.plot(ts_pos_combined[times_index:+50*gen_index], pred_x_forgraph[dataset_value, times_index:+50*gen_index, i*(k+1)+deriv_index], 'r',
                 label='learned trajectory (t>0)')

    plt.legend()
    plt.savefig('./Results_pic/tau6k3/longtimeseries/lstm_Tied_latent8_gen10_deriv0_50_wash.png', dpi=500)
    #plt.savefig('./minibatchfps200_take300_predict900_positionalvalue3.png', dpi=500)
    print('Saved visualization figure at {}'.format('./test.png'))
# Out:
# Saved visualization figure at ./test.png

# %%
with torch.no_grad():
    samp_ts_forgraph = samp_ts.detach().cpu().numpy()
    pred_x = pred_x.reshape(203, 50*gen_index, 31*(k+1)+2)
    pred_x_forgraph = pred_x.detach().cpu().numpy()
    orig_trajs_forgraph = orig_trajs
    ts_pos_forgraph = ts_pos.detach().cpu().numpy()
    ts_pos_combined = np.linspace(0, 0.25*gen_index, num=2500) 
    
    times_index = 0
    positional_value = 0
    fig, axes = plt.subplots(nrows=4, ncols=1, figsize=(15, 9))
    axes = axes.flatten()
    for i, ax in enumerate(axes):
        ax.scatter(ts_pos_combined[0:50*gen_index], orig_trajs_forgraph[i,0:50*gen_index, positional_value], label='sampled data', s = 5)
        ax.plot(ts_pos_combined[times_index:+50*gen_index], pred_x_forgraph[i, times_index:+50*gen_index, positional_value*(k+1)], 'r',
                 label='learned trajectory (t>0)')

    plt.legend()
    plt.savefig('./Results_pic/tau6k3/longtimeseries/Allrodent_Tau6k3_takenembedding_longepochgeneration_position0.png', dpi=500)
    #plt.savefig('./minibatchfps200_take300_predict900_positionalvalue3.png', dpi=500)
    print('Saved visualization figure at {}'.format('./test.png'))
# Out:
# C:\Users\shiny\AppData\Local\Temp\ipykernel_12936\1665612954.py:11: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig, axes = plt.subplots(nrows=4, ncols=1, figsize=(15, 9))
# Saved visualization figure at ./test.png

# %% [markdown]
# ## Predicting longer timescales with combining minibatches

# %%
with torch.no_grad():
    # sample from trajectorys' approx. posterior

    ts_pos = np.linspace(0, np.pi*2, num=50)
    ts_pos = torch.from_numpy(ts_pos).float().to(device)
    #ts_neg = np.linspace(-np.pi*20, 0., num=400)[::-1].copy()
    #ts_neg = torch.from_numpy(ts_neg).float().to(device)
    
    h = rec.initHidden().to(device)
    for t in reversed(range(samp_trajs.size(1))):
        obs = samp_trajs[:, t, :]
        out, h = rec.forward(obs, h)
    qz0_mean, qz0_logvar = out[:, :latent_dim], out[:, latent_dim:]
    epsilon = torch.randn(qz0_mean.size()).to(device)
    z0 = epsilon * torch.exp(.5 * qz0_logvar) + qz0_mean

    # forward in time and solve ode for reconstructions
    pred_z = odeint(func, z0, ts_pos).permute(1, 0, 2)
    pred_x = dec(pred_z)

# %%
with torch.no_grad():
    samp_ts_forgraph = samp_ts.detach().cpu().numpy()
    pred_x = pred_x.reshape(64, 1500, 46)
    pred_x_forgraph = pred_x.detach().cpu().numpy()
    samp_trajs = samp_trajs.reshape(64, 300, 46)
    samp_trajs_forgraph = samp_trajs.detach().cpu().numpy()
    ts_pos_forgraph = ts_pos.detach().cpu().numpy()
    samp_ts_combined = np.linspace(0, 299, num=300)
    ts_pos_combined = np.linspace(0, 1499, num=1500) 
    
    times_index = 0
    positional_value = 3
    fig, axes = plt.subplots(nrows=5, ncols=5, figsize=(15, 9))
    axes = axes.flatten()
    for i, ax in enumerate(axes):
        ax.scatter(samp_ts_combined[times_index:+300], samp_trajs_forgraph[i,times_index:+300, positional_value], label='sampled data', s = 5)
        ax.plot(ts_pos_combined[times_index:+1200], pred_x_forgraph[i, times_index:+1200, positional_value], 'r',
                 label='learned trajectory (t>0)')

    plt.legend()
    plt.savefig('./1200.png', dpi=500)
    #plt.savefig('./minibatchfps200_take300_predict900_positionalvalue3.png', dpi=500)
    print('Saved visualization figure at {}'.format('./test.png'))
# Out:
# Saved visualization figure at ./test.png

# %% [markdown]
# ## Predicting longer timescales: looking at each one

# %%
with torch.no_grad():
    samp_ts_forgraph = samp_ts.detach().cpu().numpy()
    pred_x_forgraph = pred_x.detach().cpu().numpy()
    samp_trajs_forgraph = samp_trajs.detach().cpu().numpy()
    ts_pos_forgraph = ts_pos.detach().cpu().numpy()
    
    times_index = 0
    positional_value = 0
    fig, axes = plt.subplots(nrows=5, ncols=5, figsize=(15, 9))
    axes = axes.flatten()
    for i, ax in enumerate(axes):
        ax.scatter(samp_ts_combined[times_index:+50], samp_trajs_forgraph[i,times_index:+50, positional_value], label='sampled data', s = 5)
        ax.plot(ts_pos_combined[times_index:+250], pred_x_forgraph[i, times_index:+250, positional_value], 'r',
                 label='learned trajectory (t>0)')

    plt.legend()
    plt.savefig('./test.png', dpi=500)
    print('Saved visualization figure at {}'.format('./test.png'))
# Out:
# Saved visualization figure at ./test.png

# %%
z0.shape
# Out:
# torch.Size([203, 4])

# %% [markdown]
# ## PCA for z0

# %%
from sklearn.decomposition import PCA
import pandas as pd

# %%
with torch.no_grad():
    ts_pos = np.linspace(0, np.pi*2*5, num=250)
    ts_pos = torch.from_numpy(ts_pos).float().to(device)
    
    h = torch.zeros(samp_trajs.shape[0], rnn_nhidden).to(device)
    
    for t in reversed(range(samp_trajs.size(1))):
        obs = samp_trajs[:, t, :]
        out, h = rec.forward(obs, h)
    qz0_mean, qz0_logvar = out[:, :latent_dim], out[:, latent_dim:]
    epsilon = torch.randn(qz0_mean.size()).to(device)
    z0 = epsilon * torch.exp(.5 * qz0_logvar) + qz0_mean
    z0 = z0.cpu()
    
    pca = PCA(n_components=2)
    pca.fit(z0.cpu())
    print("Explained variance:", pca.explained_variance_ratio_)
    z0_red = pca.fit_transform(z0)
    
    print(z0_red[:, 0].shape)
# Out:
# Explained variance: [0.42682021 0.34515899]
# (14616,)

# %%
z0 = z0.cpu()

# %%
    pca = PCA(n_components=2)
    pca.fit(z0.cpu())
    print("Explained variance:", pca.explained_variance_ratio_)
# Out:
# Explained variance: [0.42036639 0.36758968]

# %%
pca_z = PCA(n_components=2)
pca.fit(z0)

z0_red = pca.fit_transform(z0)

d = {'PC1': z0_red[:, 0], 'PC2': z0_red[:, 1]}
df = pd.DataFrame(d)

plt.figure()
plt.plot(z0_red[:, 0], z0_red[:, 1], 'o', label='z0 samples in 2D', linewidth=2, zorder=1)
plt.legend()
plt.savefig('./PCAgraph.png', dpi=250)

# %%
from sklearn.manifold import TSNE

# %%
time_start = time.time()
tsne = TSNE(n_components=2, verbose=1, perplexity=40, n_iter=300)
tsne_results = tsne.fit_transform(data_subset)
